# %% [markdown]
# # Please install the packages below to run the code

# %% [markdown]
# numpy == 1.23.5
#
# miditoolkit
#
# transformers
#
# torch

# %% [markdown]
# # Midi tutorial

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import miditoolkit
import copy
import pickle

# %% [markdown]
# ## Some functions

# %%
# parameters for input
DEFAULT_VELOCITY_BINS = np.linspace(0, 128, 32+1, dtype=int)
DEFAULT_FRACTION = 16
DEFAULT_DURATION_BINS = np.arange(60, 3841, 60, dtype=int)
DEFAULT_TEMPO_INTERVALS = [range(30, 90), range(90, 150), range(150, 210)]

# parameters for output
DEFAULT_RESOLUTION = 480

# define "Item" for general storage
class Item(object):
    def __init__(self, name, start, end, velocity, pitch):
        self.name = name
        self.start = start
        self.end = end
        self.velocity = velocity
        self.pitch = pitch

    def __repr__(self):
        return 'Item(name={}, start={}, end={}, velocity={}, pitch={})'.format(
            self.name, self.start, self.end, self.velocity, self.pitch)

# read notes and tempo changes from midi (assume there is only one track)
def read_items(file_path):
    midi_obj = miditoolkit.midi.parser.MidiFile(file_path)
    # note
    note_items = []
    notes = midi_obj.instruments[0].notes
    notes.sort(key=lambda x: (x.start, x.pitch))
    for note in notes:
        note_items.append(Item(
            name='Note', 
            start=note.start, 
            end=note.end, 
            velocity=note.velocity, 
            pitch=note.pitch))
    note_items.sort(key=lambda x: x.start)
    # tempo
    tempo_items = []
    for tempo in midi_obj.tempo_changes:
        tempo_items.append(Item(
            name='Tempo',
            start=tempo.time,
            end=None,
            velocity=None,
            pitch=int(tempo.tempo)))
    tempo_items.sort(key=lambda x: x.start)
    # expand to all beat
    max_tick = tempo_items[-1].start
    existing_ticks = {item.start: item.pitch for item in tempo_items}
    wanted_ticks = np.arange(0, max_tick+1, DEFAULT_RESOLUTION)
    output = []
    for tick in wanted_ticks:
        if tick in existing_ticks:
            output.append(Item(
                name='Tempo',
                start=tick,
                end=None,
                velocity=None,
                pitch=existing_ticks[tick]))
        else:
            output.append(Item(
                name='Tempo',
                start=tick,
                end=None,
                velocity=None,
                pitch=output[-1].pitch))
    tempo_items = output
    return note_items, tempo_items

# quantize items
def quantize_items(items, ticks=120):
    # grid
    grids = np.arange(0, items[-1].start, ticks, dtype=int)
    # process
    for item in items:
        index = np.argmin(abs(grids - item.start))
        shift = grids[index] - item.start
        item.start += shift
        item.end += shift
    return items      

# extract chord
def chord_extract(midi_path, max_time):
    midi_obj = miditoolkit.midi.parser.MidiFile(midi_path)
    interval = midi_obj.ticks_per_beat * 1
    chord_items = []
    ###
    # implement your chord extraction here
    # it's fine if you don't use chord items
    ###
    return chord_items

# group items
def group_items(items, max_time, ticks_per_bar=DEFAULT_RESOLUTION*4):
    items.sort(key=lambda x: x.start)
    downbeats = np.arange(0, max_time+ticks_per_bar, ticks_per_bar)
    groups = []
    for db1, db2 in zip(downbeats[:-1], downbeats[1:]):
        insiders = []
        for item in items:
            if (item.start >= db1) and (item.start < db2):
                insiders.append(item)
        overall = [db1] + insiders + [db2]
        groups.append(overall)
    return groups

# define "Event" for event storage
class Event(object):
    def __init__(self, name, time, value, text):
        self.name = name
        self.time = time
        self.value = value
        self.text = text

    def __repr__(self):
        return 'Event(name={}, time={}, value={}, text={})'.format(
            self.name, self.time, self.value, self.text)

# item to event
def item2event(groups):
    events = []
    n_downbeat = 0
    for i in range(len(groups)):
        if 'Note' not in [item.name for item in groups[i][1:-1]]:
            continue
        bar_st, bar_et = groups[i][0], groups[i][-1]
        n_downbeat += 1
        events.append(Event(
            name='Bar',
            time=None, 
            value=None,
            text='{}'.format(n_downbeat)))
        for item in groups[i][1:-1]:
            # position
            flags = np.linspace(bar_st, bar_et, DEFAULT_FRACTION, endpoint=False)
            index = np.argmin(abs(flags-item.start))
            events.append(Event(
                name='Position', 
                time=item.start,
                value='{}/{}'.format(index+1, DEFAULT_FRACTION),
                text='{}'.format(item.start)))
            if item.name == 'Note':
                # velocity
                velocity_index = np.searchsorted(
                    DEFAULT_VELOCITY_BINS, 
                    item.velocity, 
                    side='right') - 1
                events.append(Event(
                    name='Note Velocity',
                    time=item.start, 
                    value=velocity_index,
                    text='{}/{}'.format(item.velocity, DEFAULT_VELOCITY_BINS[velocity_index])))
                # pitch
                events.append(Event(
                    name='Note On',
                    time=item.start, 
                    value=item.pitch,
                    text='{}'.format(item.pitch)))
                # duration
                duration = item.end - item.start
                index = np.argmin(abs(DEFAULT_DURATION_BINS-duration))
                events.append(Event(
                    name='Note Duration',
                    time=item.start,
                    value=index,
                    text='{}/{}'.format(duration, DEFAULT_DURATION_BINS[index])))
            elif item.name == 'Chord':
                events.append(Event(
                    name='Chord', 
                    time=item.start,
                    value=item.pitch,
                    text='{}'.format(item.pitch)))
            elif item.name == 'Tempo':
                tempo = item.pitch
                if tempo in DEFAULT_TEMPO_INTERVALS[0]:
                    tempo_style = Event('Tempo Class', item.start, 'slow', None)
                    tempo_value = Event('Tempo Value', item.start, 
                        tempo-DEFAULT_TEMPO_INTERVALS[0].start, None)
                elif tempo in DEFAULT_TEMPO_INTERVALS[1]:
                    tempo_style = Event('Tempo Class', item.start, 'mid', None)
                    tempo_value = Event('Tempo Value', item.start, 
                        tempo-DEFAULT_TEMPO_INTERVALS[1].start, None)
                elif tempo in DEFAULT_TEMPO_INTERVALS[2]:
                    tempo_style = Event('Tempo Class', item.start, 'fast', None)
                    tempo_value = Event('Tempo Value', item.start, 
                        tempo-DEFAULT_TEMPO_INTERVALS[2].start, None)
                elif tempo < DEFAULT_TEMPO_INTERVALS[0].start:
                    tempo_style = Event('Tempo Class', item.start, 'slow', None)
                    tempo_value = Event('Tempo Value', item.start, 0, None)
                elif tempo > DEFAULT_TEMPO_INTERVALS[2].stop:
                    tempo_style = Event('Tempo Class', item.start, 'fast', None)
                    tempo_value = Event('Tempo Value', item.start, 59, None)
                events.append(tempo_style)
                events.append(tempo_value)     
    return events

#############################################################################################
# WRITE MIDI
#############################################################################################
def word_to_event(words, word2event):
    events = []
    for word in words:
        event_name, event_value = word2event.get(word).split('_')
        events.append(Event(event_name, None, event_value, None))
    return events

def write_midi(words, word2event, output_path, prompt_path=None):
    events = word_to_event(words, word2event)
    # get downbeat and note (no time)
    temp_notes = []
    temp_chords = []
    temp_tempos = []
    for i in range(len(events)-3):
        if events[i].name == 'Bar' and i > 0:
            temp_notes.append('Bar')
            temp_chords.append('Bar')
            temp_tempos.append('Bar')
        elif events[i].name == 'Position' and \
            events[i+1].name == 'Note Velocity' and \
            events[i+2].name == 'Note On' and \
            events[i+3].name == 'Note Duration':
            # start time and end time from position
            position = int(events[i].value.split('/')[0]) - 1
            # velocity
            index = int(events[i+1].value)
            velocity = int(DEFAULT_VELOCITY_BINS[index])
            # pitch
            pitch = int(events[i+2].value)
            # duration
            index = int(events[i+3].value)
            duration = DEFAULT_DURATION_BINS[index]
            # adding
            temp_notes.append([position, velocity, pitch, duration])
        elif events[i].name == 'Position' and events[i+1].name == 'Chord':
            position = int(events[i].value.split('/')[0]) - 1
            temp_chords.append([position, events[i+1].value])
        elif events[i].name == 'Position' and \
            events[i+1].name == 'Tempo Class' and \
            events[i+2].name == 'Tempo Value':
            position = int(events[i].value.split('/')[0]) - 1
            if events[i+1].value == 'slow':
                tempo = DEFAULT_TEMPO_INTERVALS[0].start + int(events[i+2].value)
            elif events[i+1].value == 'mid':
                tempo = DEFAULT_TEMPO_INTERVALS[1].start + int(events[i+2].value)
            elif events[i+1].value == 'fast':
                tempo = DEFAULT_TEMPO_INTERVALS[2].start + int(events[i+2].value)
            temp_tempos.append([position, tempo])
    # get specific time for notes
    ticks_per_beat = DEFAULT_RESOLUTION
    ticks_per_bar = DEFAULT_RESOLUTION * 4 # assume 4/4
    notes = []
    current_bar = 0
    for note in temp_notes:
        if note == 'Bar':
            current_bar += 1
        else:
            position, velocity, pitch, duration = note
            # position (start time)
            current_bar_st = current_bar * ticks_per_bar
            current_bar_et = (current_bar + 1) * ticks_per_bar
            flags = np.linspace(current_bar_st, current_bar_et, DEFAULT_FRACTION, endpoint=False, dtype=int)
            st = flags[position]
            # duration (end time)
            et = st + duration
            notes.append(miditoolkit.Note(velocity, pitch, st, et))
    # get specific time for chords
    if len(temp_chords) > 0:
        chords = []
        current_bar = 0
        for chord in temp_chords:
            if chord == 'Bar':
                current_bar += 1
            else:
                position, value = chord
                # position (start time)
                current_bar_st = current_bar * ticks_per_bar
                current_bar_et = (current_bar + 1) * ticks_per_bar
                flags = np.linspace(current_bar_st, current_bar_et, DEFAULT_FRACTION, endpoint=False, dtype=int)
                st = flags[position]
                chords.append([st, value])
    # get specific time for tempos
    tempos = []
    current_bar = 0
    for tempo in temp_tempos:
        if tempo == 'Bar':
            current_bar += 1
        else:
            position, value = tempo
            # position (start time)
            current_bar_st = current_bar * ticks_per_bar
            current_bar_et = (current_bar + 1) * ticks_per_bar
            flags = np.linspace(current_bar_st, current_bar_et, DEFAULT_FRACTION, endpoint=False, dtype=int)
            st = flags[position]
            tempos.append([int(st), value])
    # write
    if prompt_path:
        midi = miditoolkit.midi.parser.MidiFile(prompt_path)
        #
        last_time = DEFAULT_RESOLUTION * 4 * 4
        # note shift
        for note in notes:
            note.start += last_time
            note.end += last_time
        midi.instruments[0].notes.extend(notes)
        # tempo changes
        temp_tempos = []
        for tempo in midi.tempo_changes:
            if tempo.time < DEFAULT_RESOLUTION*4*4:
                temp_tempos.append(tempo)
            else:
                break
        for st, bpm in tempos:
            st += last_time
            temp_tempos.append(miditoolkit.midi.containers.TempoChange(bpm, st))
        midi.tempo_changes = temp_tempos
        # write chord into marker
        if len(temp_chords) > 0:
            for c in chords:
                midi.markers.append(
                    miditoolkit.midi.containers.Marker(text=c[1], time=c[0]+last_time))
    else:
        midi = miditoolkit.midi.parser.MidiFile()
        midi.ticks_per_beat = DEFAULT_RESOLUTION
        # write instrument
        inst = miditoolkit.midi.containers.Instrument(0, is_drum=False)
        inst.notes = notes
        midi.instruments.append(inst)
        # write tempo
        tempo_changes = []
        for st, bpm in tempos:
            tempo_changes.append(miditoolkit.midi.containers.TempoChange(bpm, st))
        midi.tempo_changes = tempo_changes
        # write chord into marker
        if len(temp_chords) > 0:
            for c in chords:
                midi.markers.append(
                    miditoolkit.midi.containers.Marker(text=c[1], time=c[0]))
    # write
    midi.dump(output_path)

# %% [markdown]
# ## Convert midi 2 remi tokens

# %% [markdown]
# ### 0. Take a look at midi file

# %%
# change your midi file path here
path = '../1.mid'
midi = miditoolkit.midi.parser.MidiFile(path)
print(midi)
# Out:
# ticks per beat: 8
# max tick: 1090
# tempo changes: 1
# time sig: 1
# key sig: 0
# markers: 0
# lyrics: False
# instruments: 1

# %%
# notes
print('Notes')
for inst in midi.instruments:
    print(inst) 
    print(*inst.notes[0:10], sep='\n')
# temples
print('\nTempos')
print(*midi.tempo_changes[0:10], sep='\n')
# Out:
# Notes
# Instrument(program=0, is_drum=False, name=Acoustic Grand Piano) - 659 notes
# Note(velocity=31, pitch=65, start=0, end=1)
# Note(velocity=87, pitch=77, start=32, end=33)
# Note(velocity=39, pitch=91, start=0, end=41)
# Note(velocity=27, pitch=79, start=32, end=50)
# Note(velocity=27, pitch=100, start=32, end=64)
# Note(velocity=35, pitch=25, start=31, end=65)
# Note(velocity=51, pitch=72, start=32, end=66)
# Note(velocity=31, pitch=73, start=32, end=66)
# Note(velocity=27, pitch=101, start=0, end=70)
# Note(velocity=83, pitch=91, start=32, end=96)
#
# Tempos
# 120.0 BPM at 0 ticks

# %% [markdown]
# ### 1. Read midi and convert to Item object

# %%
note_items, tempo_items = read_items(path)

print('Note items')
print(*note_items[0:10], sep='\n')
print('\nTempo items')
print(*tempo_items[0:10], sep='\n')
# Out:
# Note items
# Item(name=Note, start=0, end=1, velocity=31, pitch=65)
# Item(name=Note, start=0, end=41, velocity=39, pitch=91)
# Item(name=Note, start=0, end=70, velocity=27, pitch=101)
# Item(name=Note, start=31, end=65, velocity=35, pitch=25)
# Item(name=Note, start=32, end=66, velocity=51, pitch=72)
# Item(name=Note, start=32, end=66, velocity=31, pitch=73)
# Item(name=Note, start=32, end=33, velocity=87, pitch=77)
# Item(name=Note, start=32, end=50, velocity=27, pitch=79)
# Item(name=Note, start=32, end=100, velocity=83, pitch=79)
# Item(name=Note, start=32, end=116, velocity=79, pitch=87)
#
# Tempo items
# Item(name=Tempo, start=0, end=None, velocity=None, pitch=120)

# %% [markdown]
# ### 2. Quantize note items

# %%
note_items = quantize_items(note_items)

print('Quantized note items')
print(*note_items[:10], sep='\n')
# Out:
# Quantized note items
# Item(name=Note, start=0, end=1, velocity=31, pitch=65)
# Item(name=Note, start=0, end=41, velocity=39, pitch=91)
# Item(name=Note, start=0, end=70, velocity=27, pitch=101)
# Item(name=Note, start=0, end=34, velocity=35, pitch=25)
# Item(name=Note, start=0, end=34, velocity=51, pitch=72)
# Item(name=Note, start=0, end=34, velocity=31, pitch=73)
# Item(name=Note, start=0, end=1, velocity=87, pitch=77)
# Item(name=Note, start=0, end=18, velocity=27, pitch=79)
# Item(name=Note, start=0, end=68, velocity=83, pitch=79)
# Item(name=Note, start=0, end=84, velocity=79, pitch=87)

# %% [markdown]
# ### 3. extract chord (if needed)

# %%
chord_items = chord_extract(path, note_items[-1].end)

print('Chord items')
print(*chord_items[:10], sep='\n')
# Out:
# Chord items

# %% [markdown]
# ### 4. group items

# %%
# if using chord items
# items = chord_items + tempo_items + note_items

# if not using chord items
items = tempo_items + note_items

max_time = note_items[-1].end
groups = group_items(items, max_time)

for g in groups:
    print(*g, sep='\n')
    print()
# Out:
# 0
# Item(name=Tempo, start=0, end=None, velocity=None, pitch=120)
# Item(name=Note, start=0, end=1, velocity=31, pitch=65)
# Item(name=Note, start=0, end=41, velocity=39, pitch=91)
# Item(name=Note, start=0, end=70, velocity=27, pitch=101)
# Item(name=Note, start=0, end=34, velocity=35, pitch=25)
# Item(name=Note, start=0, end=34, velocity=51, pitch=72)
# Item(name=Note, start=0, end=34, velocity=31, pitch=73)
# Item(name=Note, start=0, end=1, velocity=87, pitch=77)
# Item(name=Note, start=0, end=18, velocity=27, pitch=79)
# Item(name=Note, start=0, end=68, velocity=83, pitch=79)
# Item(name=Note, start=0, end=84, velocity=79, pitch=87)
# Item(name=Note, start=0, end=64, velocity=83, pitch=91)
# Item(name=Note, start=0, end=94, velocity=27, pitch=96)
# Item(name=Note, start=0, end=32, velocity=27, pitch=100)
# Item(name=Note, start=0, end=70, velocity=31, pitch=101)
# Item(name=Note, start=0, end=90, velocity=83, pitch=101)
# Item(name=Note, start=120, end=208, velocity=27, pitch=65)
# Item(name=Note, start=120, end=196, velocity=27, pitch=79)
# Item(name=Note, start=120, end=212, velocity=87, pitch=82)
# Item(name=Note, start=120, end=214, velocity=31, pitch=94)
# Item(name=Note, start=120, end=200, velocity=27, pitch=101)
# Item(name=Note, start=120, end=210, velocity=35, pitch=101)
# Item(name=Note, start=120, end=160, velocity=31, pitch=58)
# Item(name=Note, start=120, end=154, velocity=35, pitch=65)
# Item(name=Note, start=120, end=182, velocity=31, pitch=65)
# Item(name=Note, start=120, end=158, velocity=23, pitch=75)
# Item(name=Note, start=120, end=137, velocity=43, pitch=79)
# Item(name=Note, start=120, end=188, velocity=83, pitch=89)
# Item(name=Note, start=120, end=210, velocity=83, pitch=98)
# Item(name=Note, start=120, end=184, velocity=27, pitch=67)
# Item(name=Note, start=120, end=129, velocity=35, pitch=77)
# Item(name=Note, start=120, end=186, velocity=83, pitch=79)
# Item(name=Note, start=120, end=170, velocity=71, pitch=80)
# Item(name=Note, start=120, end=186, velocity=83, pitch=82)
# Item(name=Note, start=120, end=154, velocity=31, pitch=87)
# Item(name=Note, start=120, end=176, velocity=31, pitch=96)
# Item(name=Note, start=120, end=176, velocity=27, pitch=96)
# Item(name=Note, start=120, end=137, velocity=83, pitch=99)
# Item(name=Note, start=240, end=300, velocity=31, pitch=27)
# Item(name=Note, start=240, end=311, velocity=27, pitch=39)
# Item(name=Note, start=240, end=282, velocity=39, pitch=75)
# Item(name=Note, start=240, end=274, velocity=83, pitch=79)
# Item(name=Note, start=240, end=274, velocity=31, pitch=79)
# Item(name=Note, start=240, end=276, velocity=31, pitch=79)
# Item(name=Note, start=240, end=282, velocity=83, pitch=82)
# Item(name=Note, start=240, end=306, velocity=87, pitch=84)
# Item(name=Note, start=240, end=288, velocity=83, pitch=87)
# Item(name=Note, start=240, end=294, velocity=83, pitch=87)
# Item(name=Note, start=240, end=308, velocity=83, pitch=87)
# Item(name=Note, start=240, end=334, velocity=83, pitch=94)
# Item(name=Note, start=240, end=288, velocity=31, pitch=96)
# Item(name=Note, start=240, end=292, velocity=83, pitch=103)
# Item(name=Note, start=240, end=278, velocity=67, pitch=79)
# Item(name=Note, start=240, end=312, velocity=83, pitch=84)
# Item(name=Note, start=240, end=294, velocity=83, pitch=87)
# Item(name=Note, start=240, end=306, velocity=83, pitch=87)
# Item(name=Note, start=240, end=257, velocity=47, pitch=88)
# Item(name=Note, start=240, end=245, velocity=83, pitch=89)
# Item(name=Note, start=240, end=263, velocity=83, pitch=91)
# Item(name=Note, start=240, end=263, velocity=87, pitch=91)
# Item(name=Note, start=240, end=290, velocity=79, pitch=92)
# Item(name=Note, start=240, end=241, velocity=59, pitch=95)
# Item(name=Note, start=240, end=324, velocity=83, pitch=98)
# Item(name=Note, start=240, end=280, velocity=43, pitch=103)
# Item(name=Note, start=240, end=253, velocity=39, pitch=24)
# Item(name=Note, start=240, end=332, velocity=31, pitch=36)
# Item(name=Note, start=240, end=302, velocity=83, pitch=75)
# Item(name=Note, start=240, end=306, velocity=83, pitch=77)
# Item(name=Note, start=240, end=326, velocity=83, pitch=77)
# Item(name=Note, start=240, end=306, velocity=83, pitch=79)
# Item(name=Note, start=240, end=334, velocity=63, pitch=79)
# Item(name=Note, start=240, end=269, velocity=35, pitch=81)
# Item(name=Note, start=240, end=302, velocity=35, pitch=87)
# Item(name=Note, start=240, end=302, velocity=83, pitch=87)
# Item(name=Note, start=240, end=308, velocity=83, pitch=87)
# Item(name=Note, start=240, end=324, velocity=67, pitch=88)
# Item(name=Note, start=240, end=261, velocity=31, pitch=89)
# Item(name=Note, start=240, end=318, velocity=39, pitch=89)
# Item(name=Note, start=240, end=268, velocity=31, pitch=91)
# Item(name=Note, start=240, end=292, velocity=83, pitch=91)
# Item(name=Note, start=240, end=306, velocity=35, pitch=91)
# Item(name=Note, start=240, end=322, velocity=87, pitch=91)
# Item(name=Note, start=240, end=324, velocity=27, pitch=91)
# Item(name=Note, start=240, end=268, velocity=39, pitch=96)
# Item(name=Note, start=240, end=276, velocity=31, pitch=96)
# Item(name=Note, start=240, end=302, velocity=83, pitch=96)
# Item(name=Note, start=240, end=259, velocity=43, pitch=99)
# Item(name=Note, start=240, end=269, velocity=83, pitch=101)
# Item(name=Note, start=240, end=318, velocity=83, pitch=89)
# Item(name=Note, start=240, end=328, velocity=35, pitch=91)
# Item(name=Note, start=240, end=278, velocity=87, pitch=99)
# Item(name=Note, start=240, end=308, velocity=31, pitch=27)
# Item(name=Note, start=240, end=314, velocity=63, pitch=99)
# Item(name=Note, start=240, end=282, velocity=35, pitch=103)
# Item(name=Note, start=240, end=318, velocity=83, pitch=104)
# Item(name=Note, start=240, end=334, velocity=35, pitch=32)
# Item(name=Note, start=240, end=336, velocity=83, pitch=32)
# Item(name=Note, start=240, end=308, velocity=83, pitch=36)
# Item(name=Note, start=240, end=258, velocity=35, pitch=39)
# Item(name=Note, start=240, end=306, velocity=39, pitch=44)
# Item(name=Note, start=240, end=269, velocity=39, pitch=60)
# Item(name=Note, start=240, end=268, velocity=59, pitch=63)
# Item(name=Note, start=240, end=278, velocity=31, pitch=65)
# Item(name=Note, start=240, end=265, velocity=43, pitch=75)
# Item(name=Note, start=240, end=322, velocity=83, pitch=79)
# Item(name=Note, start=240, end=280, velocity=47, pitch=80)
# Item(name=Note, start=240, end=272, velocity=43, pitch=87)
# Item(name=Note, start=240, end=274, velocity=39, pitch=87)
# Item(name=Note, start=240, end=336, velocity=75, pitch=94)
# Item(name=Note, start=240, end=336, velocity=83, pitch=95)
# Item(name=Note, start=240, end=304, velocity=83, pitch=96)
# Item(name=Note, start=240, end=314, velocity=83, pitch=96)
# Item(name=Note, start=240, end=274, velocity=31, pitch=99)
# Item(name=Note, start=240, end=259, velocity=31, pitch=56)
# Item(name=Note, start=240, end=250, velocity=27, pitch=60)
# Item(name=Note, start=240, end=310, velocity=47, pitch=63)
# Item(name=Note, start=240, end=259, velocity=83, pitch=87)
# Item(name=Note, start=240, end=312, velocity=83, pitch=96)
# Item(name=Note, start=240, end=314, velocity=87, pitch=96)
# Item(name=Note, start=240, end=314, velocity=87, pitch=101)
# Item(name=Note, start=240, end=300, velocity=43, pitch=44)
# Item(name=Note, start=240, end=248, velocity=39, pitch=51)
# Item(name=Note, start=240, end=272, velocity=23, pitch=51)
# Item(name=Note, start=240, end=289, velocity=31, pitch=51)
# Item(name=Note, start=240, end=290, velocity=27, pitch=56)
# Item(name=Note, start=240, end=253, velocity=31, pitch=58)
# Item(name=Note, start=240, end=272, velocity=39, pitch=60)
# Item(name=Note, start=240, end=272, velocity=43, pitch=60)
# Item(name=Note, start=240, end=284, velocity=27, pitch=60)
# Item(name=Note, start=240, end=312, velocity=31, pitch=63)
# Item(name=Note, start=240, end=314, velocity=67, pitch=63)
# Item(name=Note, start=240, end=270, velocity=83, pitch=72)
# Item(name=Note, start=240, end=273, velocity=83, pitch=75)
# Item(name=Note, start=240, end=271, velocity=83, pitch=80)
# Item(name=Note, start=240, end=280, velocity=87, pitch=80)
# Item(name=Note, start=240, end=262, velocity=83, pitch=87)
# Item(name=Note, start=240, end=284, velocity=83, pitch=87)
# Item(name=Note, start=240, end=306, velocity=87, pitch=89)
# Item(name=Note, start=240, end=322, velocity=39, pitch=90)
# Item(name=Note, start=240, end=332, velocity=39, pitch=93)
# Item(name=Note, start=240, end=308, velocity=31, pitch=96)
# Item(name=Note, start=240, end=249, velocity=35, pitch=99)
# Item(name=Note, start=240, end=264, velocity=39, pitch=99)
# Item(name=Note, start=240, end=270, velocity=35, pitch=99)
# Item(name=Note, start=240, end=270, velocity=83, pitch=99)
# Item(name=Note, start=240, end=282, velocity=83, pitch=99)
# Item(name=Note, start=240, end=300, velocity=79, pitch=99)
# Item(name=Note, start=240, end=306, velocity=83, pitch=99)
# Item(name=Note, start=240, end=278, velocity=35, pitch=104)
# Item(name=Note, start=360, end=396, velocity=31, pitch=54)
# Item(name=Note, start=360, end=407, velocity=31, pitch=60)
# Item(name=Note, start=360, end=382, velocity=83, pitch=75)
# Item(name=Note, start=360, end=411, velocity=27, pitch=80)
# Item(name=Note, start=360, end=430, velocity=83, pitch=87)
# Item(name=Note, start=360, end=437, velocity=83, pitch=87)
# Item(name=Note, start=360, end=446, velocity=83, pitch=89)
# Item(name=Note, start=360, end=416, velocity=35, pitch=99)
# Item(name=Note, start=360, end=406, velocity=47, pitch=99)
# Item(name=Note, start=360, end=406, velocity=27, pitch=101)
# Item(name=Note, start=360, end=430, velocity=79, pitch=103)
# Item(name=Note, start=360, end=394, velocity=43, pitch=51)
# Item(name=Note, start=360, end=384, velocity=83, pitch=58)
# Item(name=Note, start=360, end=420, velocity=71, pitch=63)
# Item(name=Note, start=360, end=384, velocity=27, pitch=65)
# Item(name=Note, start=360, end=398, velocity=83, pitch=65)
# Item(name=Note, start=360, end=424, velocity=31, pitch=65)
# Item(name=Note, start=360, end=394, velocity=35, pitch=75)
# Item(name=Note, start=360, end=450, velocity=83, pitch=77)
# Item(name=Note, start=360, end=394, velocity=55, pitch=94)
# Item(name=Note, start=360, end=402, velocity=43, pitch=97)
# Item(name=Note, start=360, end=400, velocity=31, pitch=99)
# Item(name=Note, start=360, end=402, velocity=39, pitch=99)
# Item(name=Note, start=360, end=424, velocity=83, pitch=99)
# Item(name=Note, start=360, end=434, velocity=87, pitch=99)
# Item(name=Note, start=360, end=442, velocity=39, pitch=99)
# Item(name=Note, start=360, end=442, velocity=27, pitch=99)
# Item(name=Note, start=360, end=442, velocity=23, pitch=99)
# Item(name=Note, start=360, end=442, velocity=83, pitch=99)
# Item(name=Note, start=360, end=442, velocity=83, pitch=99)
# Item(name=Note, start=360, end=442, velocity=83, pitch=99)
# Item(name=Note, start=360, end=440, velocity=27, pitch=101)
# Item(name=Note, start=360, end=456, velocity=23, pitch=101)
# Item(name=Note, start=360, end=438, velocity=27, pitch=103)
# Item(name=Note, start=360, end=442, velocity=83, pitch=103)
# Item(name=Note, start=360, end=413, velocity=35, pitch=58)
# Item(name=Note, start=360, end=421, velocity=31, pitch=63)
# Item(name=Note, start=360, end=405, velocity=23, pitch=65)
# Item(name=Note, start=360, end=435, velocity=35, pitch=99)
# Item(name=Note, start=360, end=435, velocity=35, pitch=99)
# Item(name=Note, start=360, end=408, velocity=31, pitch=100)
# Item(name=Note, start=360, end=422, velocity=35, pitch=63)
# Item(name=Note, start=360, end=410, velocity=31, pitch=65)
# Item(name=Note, start=360, end=436, velocity=87, pitch=87)
# Item(name=Note, start=360, end=440, velocity=23, pitch=89)
# Item(name=Note, start=360, end=414, velocity=87, pitch=91)
# Item(name=Note, start=360, end=449, velocity=87, pitch=99)
# Item(name=Note, start=360, end=438, velocity=31, pitch=63)
# Item(name=Note, start=360, end=434, velocity=27, pitch=87)
# Item(name=Note, start=360, end=409, velocity=27, pitch=91)
# Item(name=Note, start=360, end=430, velocity=27, pitch=91)
# Item(name=Note, start=360, end=437, velocity=27, pitch=99)
# Item(name=Note, start=360, end=442, velocity=87, pitch=63)
# Item(name=Note, start=360, end=432, velocity=27, pitch=91)
# Item(name=Note, start=360, end=408, velocity=35, pitch=101)
# Item(name=Note, start=360, end=436, velocity=27, pitch=101)
# Item(name=Note, start=360, end=456, velocity=83, pitch=65)
# Item(name=Note, start=360, end=442, velocity=27, pitch=70)
# Item(name=Note, start=360, end=430, velocity=83, pitch=75)
# Item(name=Note, start=360, end=428, velocity=83, pitch=79)
# Item(name=Note, start=360, end=440, velocity=87, pitch=79)
# Item(name=Note, start=360, end=428, velocity=83, pitch=87)
# Item(name=Note, start=360, end=396, velocity=31, pitch=25)
# Item(name=Note, start=360, end=426, velocity=27, pitch=101)
# Item(name=Note, start=360, end=396, velocity=83, pitch=103)
# Item(name=Note, start=360, end=424, velocity=39, pitch=63)
# Item(name=Note, start=360, end=454, velocity=87, pitch=87)
# Item(name=Note, start=360, end=456, velocity=87, pitch=87)
# Item(name=Note, start=360, end=454, velocity=27, pitch=89)
# Item(name=Note, start=360, end=425, velocity=83, pitch=101)
# Item(name=Note, start=360, end=438, velocity=31, pitch=101)
# Item(name=Note, start=480, end=532, velocity=83, pitch=65)
# Item(name=Note, start=480, end=534, velocity=35, pitch=70)
# Item(name=Note, start=480, end=497, velocity=27, pitch=99)
# Item(name=Note, start=480, end=481, velocity=83, pitch=72)
# Item(name=Note, start=480, end=513, velocity=83, pitch=75)
# Item(name=Note, start=480, end=514, velocity=31, pitch=80)
# Item(name=Note, start=480, end=530, velocity=87, pitch=94)
# Item(name=Note, start=480, end=525, velocity=35, pitch=99)
# Item(name=Note, start=480, end=530, velocity=35, pitch=99)
# Item(name=Note, start=480, end=528, velocity=83, pitch=101)
# Item(name=Note, start=480, end=530, velocity=31, pitch=58)
# Item(name=Note, start=480, end=546, velocity=27, pitch=58)
# Item(name=Note, start=480, end=546, velocity=31, pitch=63)
# Item(name=Note, start=480, end=543, velocity=31, pitch=65)
# Item(name=Note, start=480, end=491, velocity=27, pitch=72)
# Item(name=Note, start=480, end=562, velocity=51, pitch=72)
# Item(name=Note, start=480, end=514, velocity=35, pitch=75)
# Item(name=Note, start=480, end=516, velocity=31, pitch=75)
# Item(name=Note, start=480, end=534, velocity=83, pitch=75)
# Item(name=Note, start=480, end=562, velocity=83, pitch=77)
# Item(name=Note, start=480, end=534, velocity=83, pitch=79)
# Item(name=Note, start=480, end=537, velocity=43, pitch=79)
# Item(name=Note, start=480, end=546, velocity=83, pitch=80)
# Item(name=Note, start=480, end=576, velocity=83, pitch=82)
# Item(name=Note, start=480, end=550, velocity=83, pitch=87)
# Item(name=Note, start=480, end=543, velocity=83, pitch=91)
# Item(name=Note, start=480, end=544, velocity=83, pitch=91)
# Item(name=Note, start=480, end=548, velocity=83, pitch=91)
# Item(name=Note, start=480, end=530, velocity=87, pitch=99)
# Item(name=Note, start=480, end=534, velocity=27, pitch=99)
# Item(name=Note, start=480, end=546, velocity=87, pitch=101)
# Item(name=Note, start=480, end=548, velocity=83, pitch=101)
# Item(name=Note, start=480, end=530, velocity=31, pitch=24)
# Item(name=Note, start=480, end=538, velocity=31, pitch=63)
# Item(name=Note, start=480, end=516, velocity=39, pitch=79)
# Item(name=Note, start=480, end=520, velocity=27, pitch=89)
# Item(name=Note, start=480, end=526, velocity=87, pitch=89)
# Item(name=Note, start=480, end=562, velocity=87, pitch=96)
# Item(name=Note, start=480, end=522, velocity=31, pitch=99)
# Item(name=Note, start=480, end=538, velocity=31, pitch=99)
# Item(name=Note, start=480, end=516, velocity=83, pitch=103)
# Item(name=Note, start=480, end=556, velocity=83, pitch=82)
# Item(name=Note, start=480, end=522, velocity=31, pitch=91)
# Item(name=Note, start=480, end=550, velocity=83, pitch=91)
# Item(name=Note, start=480, end=552, velocity=87, pitch=99)
# Item(name=Note, start=480, end=546, velocity=83, pitch=63)
# Item(name=Note, start=480, end=533, velocity=27, pitch=65)
# Item(name=Note, start=480, end=481, velocity=35, pitch=70)
# Item(name=Note, start=480, end=533, velocity=83, pitch=70)
# Item(name=Note, start=480, end=570, velocity=83, pitch=72)
# Item(name=Note, start=480, end=489, velocity=39, pitch=74)
# Item(name=Note, start=480, end=562, velocity=35, pitch=74)
# Item(name=Note, start=480, end=513, velocity=39, pitch=75)
# Item(name=Note, start=480, end=534, velocity=83, pitch=77)
# Item(name=Note, start=480, end=517, velocity=35, pitch=79)
# Item(name=Note, start=480, end=524, velocity=39, pitch=79)
# Item(name=Note, start=480, end=554, velocity=79, pitch=82)
# Item(name=Note, start=480, end=562, velocity=31, pitch=84)
# Item(name=Note, start=480, end=528, velocity=31, pitch=87)
# Item(name=Note, start=480, end=544, velocity=31, pitch=87)
# Item(name=Note, start=480, end=533, velocity=27, pitch=94)
# Item(name=Note, start=480, end=554, velocity=83, pitch=94)
# Item(name=Note, start=480, end=568, velocity=83, pitch=96)
# Item(name=Note, start=480, end=549, velocity=31, pitch=99)
# Item(name=Note, start=480, end=549, velocity=23, pitch=99)
# Item(name=Note, start=480, end=562, velocity=27, pitch=99)
# Item(name=Note, start=480, end=544, velocity=31, pitch=101)
# Item(name=Note, start=480, end=564, velocity=27, pitch=96)
# Item(name=Note, start=480, end=500, velocity=27, pitch=98)
# Item(name=Note, start=480, end=549, velocity=27, pitch=99)
# Item(name=Note, start=480, end=551, velocity=83, pitch=99)
# Item(name=Note, start=480, end=520, velocity=83, pitch=75)
# Item(name=Note, start=480, end=530, velocity=39, pitch=75)
# Item(name=Note, start=480, end=538, velocity=83, pitch=77)
# Item(name=Note, start=480, end=522, velocity=39, pitch=79)
# Item(name=Note, start=480, end=528, velocity=39, pitch=79)
# Item(name=Note, start=480, end=520, velocity=83, pitch=80)
# Item(name=Note, start=480, end=548, velocity=83, pitch=82)
# Item(name=Note, start=480, end=528, velocity=83, pitch=87)
# Item(name=Note, start=480, end=563, velocity=83, pitch=87)
# Item(name=Note, start=480, end=556, velocity=27, pitch=93)
# Item(name=Note, start=480, end=508, velocity=27, pitch=98)
# Item(name=Note, start=480, end=559, velocity=27, pitch=98)
# Item(name=Note, start=480, end=547, velocity=83, pitch=79)
# Item(name=Note, start=480, end=546, velocity=83, pitch=82)
# Item(name=Note, start=480, end=530, velocity=83, pitch=89)
# Item(name=Note, start=480, end=532, velocity=83, pitch=91)
# Item(name=Note, start=480, end=540, velocity=83, pitch=91)
# Item(name=Note, start=480, end=546, velocity=23, pitch=99)
# Item(name=Note, start=480, end=551, velocity=31, pitch=70)
# Item(name=Note, start=480, end=564, velocity=55, pitch=72)
# Item(name=Note, start=480, end=551, velocity=27, pitch=75)
# Item(name=Note, start=480, end=536, velocity=83, pitch=77)
# Item(name=Note, start=480, end=551, velocity=47, pitch=79)
# Item(name=Note, start=480, end=559, velocity=83, pitch=79)
# Item(name=Note, start=480, end=574, velocity=83, pitch=84)
# Item(name=Note, start=480, end=502, velocity=83, pitch=86)
# Item(name=Note, start=480, end=562, velocity=27, pitch=86)
# Item(name=Note, start=480, end=559, velocity=83, pitch=87)
# Item(name=Note, start=480, end=561, velocity=27, pitch=87)
# Item(name=Note, start=480, end=547, velocity=31, pitch=89)
# Item(name=Note, start=480, end=555, velocity=39, pitch=91)
# Item(name=Note, start=480, end=566, velocity=83, pitch=91)
# Item(name=Note, start=480, end=562, velocity=87, pitch=96)
# Item(name=Note, start=480, end=547, velocity=27, pitch=99)
# Item(name=Note, start=480, end=556, velocity=83, pitch=99)
# Item(name=Note, start=480, end=509, velocity=23, pitch=24)
# Item(name=Note, start=480, end=550, velocity=83, pitch=99)
# Item(name=Note, start=480, end=550, velocity=27, pitch=99)
# Item(name=Note, start=600, end=629, velocity=35, pitch=30)
# Item(name=Note, start=600, end=631, velocity=83, pitch=36)
# Item(name=Note, start=600, end=651, velocity=31, pitch=77)
# Item(name=Note, start=600, end=632, velocity=39, pitch=80)
# Item(name=Note, start=600, end=676, velocity=31, pitch=87)
# Item(name=Note, start=600, end=676, velocity=83, pitch=90)
# Item(name=Note, start=600, end=644, velocity=83, pitch=94)
# Item(name=Note, start=600, end=666, velocity=31, pitch=94)
# Item(name=Note, start=600, end=694, velocity=83, pitch=96)
# Item(name=Note, start=600, end=672, velocity=83, pitch=98)
# Item(name=Note, start=600, end=666, velocity=79, pitch=99)
# Item(name=Note, start=600, end=670, velocity=39, pitch=99)
# Item(name=Note, start=600, end=670, velocity=83, pitch=99)
# Item(name=Note, start=600, end=664, velocity=83, pitch=101)
# Item(name=Note, start=600, end=692, velocity=31, pitch=101)
# Item(name=Note, start=600, end=694, velocity=27, pitch=102)
# Item(name=Note, start=600, end=656, velocity=83, pitch=103)
# Item(name=Note, start=600, end=662, velocity=27, pitch=103)
# Item(name=Note, start=600, end=675, velocity=83, pitch=99)
# Item(name=Note, start=600, end=664, velocity=83, pitch=99)
# Item(name=Note, start=600, end=666, velocity=83, pitch=99)
# Item(name=Note, start=600, end=668, velocity=27, pitch=99)
# Item(name=Note, start=600, end=676, velocity=83, pitch=99)
# Item(name=Note, start=600, end=632, velocity=27, pitch=104)
# Item(name=Note, start=600, end=608, velocity=35, pitch=29)
# Item(name=Note, start=600, end=676, velocity=83, pitch=29)
# Item(name=Note, start=600, end=617, velocity=63, pitch=34)
# Item(name=Note, start=600, end=614, velocity=55, pitch=36)
# Item(name=Note, start=600, end=630, velocity=31, pitch=36)
# Item(name=Note, start=600, end=638, velocity=39, pitch=36)
# Item(name=Note, start=600, end=627, velocity=55, pitch=39)
# Item(name=Note, start=600, end=603, velocity=27, pitch=41)
# Item(name=Note, start=600, end=608, velocity=83, pitch=41)
# Item(name=Note, start=600, end=632, velocity=79, pitch=41)
# Item(name=Note, start=600, end=642, velocity=67, pitch=41)
# Item(name=Note, start=600, end=646, velocity=83, pitch=46)
# Item(name=Note, start=600, end=648, velocity=31, pitch=48)
# Item(name=Note, start=600, end=630, velocity=31, pitch=49)
# Item(name=Note, start=600, end=614, velocity=35, pitch=50)
# Item(name=Note, start=600, end=618, velocity=83, pitch=50)
# Item(name=Note, start=600, end=604, velocity=31, pitch=53)
# Item(name=Note, start=600, end=619, velocity=31, pitch=53)
# Item(name=Note, start=600, end=625, velocity=71, pitch=53)
# Item(name=Note, start=600, end=640, velocity=47, pitch=53)
# Item(name=Note, start=600, end=650, velocity=83, pitch=56)
# Item(name=Note, start=600, end=678, velocity=39, pitch=56)
# Item(name=Note, start=600, end=601, velocity=31, pitch=58)
# Item(name=Note, start=600, end=610, velocity=31, pitch=58)
# Item(name=Note, start=600, end=692, velocity=55, pitch=58)
# Item(name=Note, start=600, end=611, velocity=67, pitch=60)
# Item(name=Note, start=600, end=634, velocity=31, pitch=60)
# Item(name=Note, start=600, end=638, velocity=31, pitch=60)
# Item(name=Note, start=600, end=638, velocity=83, pitch=60)
# Item(name=Note, start=600, end=606, velocity=39, pitch=65)
# Item(name=Note, start=600, end=690, velocity=83, pitch=65)
# Item(name=Note, start=600, end=650, velocity=35, pitch=68)
# Item(name=Note, start=600, end=651, velocity=31, pitch=70)
# Item(name=Note, start=600, end=668, velocity=27, pitch=77)
# Item(name=Note, start=600, end=688, velocity=79, pitch=79)
# Item(name=Note, start=600, end=654, velocity=79, pitch=80)
# Item(name=Note, start=600, end=674, velocity=83, pitch=87)
# Item(name=Note, start=600, end=678, velocity=83, pitch=87)
# Item(name=Note, start=600, end=692, velocity=87, pitch=87)
# Item(name=Note, start=600, end=642, velocity=83, pitch=89)
# Item(name=Note, start=600, end=650, velocity=27, pitch=89)
# Item(name=Note, start=600, end=664, velocity=83, pitch=91)
# Item(name=Note, start=600, end=678, velocity=83, pitch=91)
# Item(name=Note, start=600, end=694, velocity=83, pitch=91)
# Item(name=Note, start=600, end=696, velocity=27, pitch=91)
# Item(name=Note, start=600, end=662, velocity=83, pitch=94)
# Item(name=Note, start=600, end=680, velocity=83, pitch=94)
# Item(name=Note, start=600, end=680, velocity=83, pitch=94)
# Item(name=Note, start=600, end=696, velocity=87, pitch=94)
# Item(name=Note, start=600, end=682, velocity=23, pitch=99)
# Item(name=Note, start=600, end=690, velocity=83, pitch=99)
# Item(name=Note, start=600, end=660, velocity=83, pitch=103)
# Item(name=Note, start=600, end=674, velocity=51, pitch=98)
# Item(name=Note, start=600, end=670, velocity=23, pitch=103)
# Item(name=Note, start=600, end=670, velocity=87, pitch=103)
# Item(name=Note, start=600, end=694, velocity=35, pitch=101)
# Item(name=Note, start=600, end=694, velocity=23, pitch=101)
# Item(name=Note, start=600, end=696, velocity=43, pitch=68)
# Item(name=Note, start=600, end=652, velocity=31, pitch=72)
# Item(name=Note, start=600, end=682, velocity=27, pitch=89)
# Item(name=Note, start=600, end=654, velocity=83, pitch=99)
# Item(name=Note, start=600, end=664, velocity=35, pitch=101)
# Item(name=Note, start=600, end=664, velocity=31, pitch=58)
# Item(name=Note, start=600, end=680, velocity=83, pitch=60)
# Item(name=Note, start=600, end=692, velocity=31, pitch=63)
# Item(name=Note, start=600, end=666, velocity=31, pitch=73)
# Item(name=Note, start=600, end=634, velocity=35, pitch=75)
# Item(name=Note, start=600, end=660, velocity=83, pitch=75)
# Item(name=Note, start=600, end=634, velocity=39, pitch=77)
# Item(name=Note, start=600, end=652, velocity=83, pitch=77)
# Item(name=Note, start=600, end=660, velocity=27, pitch=77)
# Item(name=Note, start=600, end=633, velocity=83, pitch=79)
# Item(name=Note, start=600, end=638, velocity=31, pitch=79)
# Item(name=Note, start=600, end=682, velocity=83, pitch=80)
# Item(name=Note, start=600, end=614, velocity=27, pitch=84)
# Item(name=Note, start=600, end=620, velocity=83, pitch=87)
# Item(name=Note, start=600, end=632, velocity=35, pitch=91)
# Item(name=Note, start=600, end=696, velocity=87, pitch=91)
# Item(name=Note, start=600, end=660, velocity=83, pitch=94)
# Item(name=Note, start=600, end=660, velocity=83, pitch=94)
# Item(name=Note, start=600, end=638, velocity=39, pitch=99)
# Item(name=Note, start=600, end=650, velocity=83, pitch=101)
# Item(name=Note, start=600, end=618, velocity=27, pitch=81)
# Item(name=Note, start=600, end=609, velocity=31, pitch=82)
# Item(name=Note, start=600, end=621, velocity=27, pitch=82)
# Item(name=Note, start=600, end=674, velocity=83, pitch=82)
# Item(name=Note, start=600, end=651, velocity=27, pitch=84)
# Item(name=Note, start=600, end=672, velocity=27, pitch=84)
# Item(name=Note, start=600, end=682, velocity=83, pitch=84)
# Item(name=Note, start=600, end=642, velocity=35, pitch=86)
# Item(name=Note, start=600, end=676, velocity=83, pitch=86)
# Item(name=Note, start=600, end=609, velocity=83, pitch=87)
# Item(name=Note, start=600, end=657, velocity=83, pitch=87)
# Item(name=Note, start=600, end=666, velocity=39, pitch=87)
# Item(name=Note, start=600, end=671, velocity=83, pitch=87)
# Item(name=Note, start=600, end=672, velocity=31, pitch=87)
# Item(name=Note, start=600, end=674, velocity=83, pitch=87)
# Item(name=Note, start=600, end=676, velocity=35, pitch=87)
# Item(name=Note, start=600, end=685, velocity=35, pitch=87)
# Item(name=Note, start=600, end=663, velocity=83, pitch=94)
# Item(name=Note, start=600, end=639, velocity=83, pitch=96)
# Item(name=Note, start=600, end=648, velocity=83, pitch=77)
# Item(name=Note, start=600, end=652, velocity=43, pitch=79)
# Item(name=Note, start=600, end=660, velocity=47, pitch=79)
# Item(name=Note, start=600, end=673, velocity=83, pitch=82)
# Item(name=Note, start=600, end=682, velocity=83, pitch=82)
# Item(name=Note, start=600, end=682, velocity=83, pitch=84)
# Item(name=Note, start=600, end=685, velocity=83, pitch=87)
# Item(name=Note, start=600, end=693, velocity=83, pitch=87)
# Item(name=Note, start=600, end=696, velocity=83, pitch=87)
# Item(name=Note, start=600, end=661, velocity=31, pitch=96)
# Item(name=Note, start=600, end=636, velocity=31, pitch=101)
# Item(name=Note, start=600, end=639, velocity=87, pitch=101)
# Item(name=Note, start=720, end=786, velocity=79, pitch=94)
# Item(name=Note, start=720, end=789, velocity=83, pitch=94)
# Item(name=Note, start=720, end=779, velocity=83, pitch=96)
# Item(name=Note, start=720, end=784, velocity=83, pitch=96)
# Item(name=Note, start=720, end=749, velocity=39, pitch=99)
# Item(name=Note, start=720, end=754, velocity=83, pitch=99)
# Item(name=Note, start=720, end=770, velocity=39, pitch=99)
# Item(name=Note, start=720, end=776, velocity=83, pitch=99)
# Item(name=Note, start=720, end=791, velocity=83, pitch=99)
# Item(name=Note, start=720, end=783, velocity=83, pitch=101)
# Item(name=Note, start=720, end=782, velocity=31, pitch=105)
# Item(name=Note, start=720, end=790, velocity=23, pitch=99)
# Item(name=Note, start=720, end=799, velocity=83, pitch=99)
# Item(name=Note, start=720, end=756, velocity=83, pitch=104)
# Item(name=Note, start=720, end=792, velocity=27, pitch=104)
# Item(name=Note, start=720, end=756, velocity=83, pitch=75)
# Item(name=Note, start=720, end=792, velocity=83, pitch=75)
# Item(name=Note, start=720, end=756, velocity=31, pitch=78)
# Item(name=Note, start=720, end=794, velocity=83, pitch=82)
# Item(name=Note, start=720, end=812, velocity=27, pitch=92)
# Item(name=Note, start=720, end=721, velocity=83, pitch=46)
# Item(name=Note, start=720, end=787, velocity=67, pitch=63)
# Item(name=Note, start=720, end=778, velocity=43, pitch=65)
# Item(name=Note, start=720, end=745, velocity=63, pitch=70)
# Item(name=Note, start=720, end=751, velocity=79, pitch=70)
# Item(name=Note, start=720, end=721, velocity=43, pitch=72)
# Item(name=Note, start=720, end=782, velocity=83, pitch=75)
# Item(name=Note, start=720, end=789, velocity=63, pitch=75)
# Item(name=Note, start=720, end=808, velocity=79, pitch=75)
# Item(name=Note, start=720, end=735, velocity=71, pitch=77)
# Item(name=Note, start=720, end=751, velocity=35, pitch=77)
# Item(name=Note, start=720, end=752, velocity=79, pitch=77)
# Item(name=Note, start=720, end=765, velocity=79, pitch=77)
# Item(name=Note, start=720, end=816, velocity=75, pitch=77)
# Item(name=Note, start=720, end=777, velocity=83, pitch=78)
# Item(name=Note, start=720, end=759, velocity=83, pitch=79)
# Item(name=Note, start=720, end=781, velocity=59, pitch=79)
# Item(name=Note, start=720, end=777, velocity=83, pitch=82)
# Item(name=Note, start=720, end=797, velocity=83, pitch=82)
# Item(name=Note, start=720, end=770, velocity=79, pitch=84)
# Item(name=Note, start=720, end=810, velocity=83, pitch=84)
# Item(name=Note, start=720, end=798, velocity=83, pitch=87)
# Item(name=Note, start=720, end=812, velocity=83, pitch=87)
# Item(name=Note, start=720, end=814, velocity=79, pitch=87)
# Item(name=Note, start=720, end=764, velocity=31, pitch=94)
# Item(name=Note, start=720, end=772, velocity=31, pitch=94)
# Item(name=Note, start=720, end=770, velocity=87, pitch=96)
# Item(name=Note, start=720, end=765, velocity=31, pitch=101)
# Item(name=Note, start=720, end=772, velocity=87, pitch=101)
# Item(name=Note, start=720, end=791, velocity=87, pitch=63)
# Item(name=Note, start=720, end=798, velocity=87, pitch=90)
# Item(name=Note, start=720, end=794, velocity=87, pitch=92)
# Item(name=Note, start=720, end=771, velocity=83, pitch=99)
# Item(name=Note, start=720, end=772, velocity=87, pitch=99)
# Item(name=Note, start=720, end=780, velocity=35, pitch=100)
# Item(name=Note, start=720, end=812, velocity=39, pitch=101)
# Item(name=Note, start=720, end=762, velocity=35, pitch=102)
# Item(name=Note, start=720, end=772, velocity=83, pitch=104)
# Item(name=Note, start=720, end=758, velocity=43, pitch=91)
# Item(name=Note, start=720, end=777, velocity=79, pitch=99)
# Item(name=Note, start=720, end=801, velocity=31, pitch=82)
# Item(name=Note, start=720, end=800, velocity=39, pitch=91)
# Item(name=Note, start=720, end=778, velocity=31, pitch=94)
# Item(name=Note, start=720, end=776, velocity=83, pitch=99)
# Item(name=Note, start=720, end=790, velocity=83, pitch=79)
# Item(name=Note, start=720, end=796, velocity=39, pitch=91)
# Item(name=Note, start=720, end=772, velocity=83, pitch=94)
# Item(name=Note, start=720, end=816, velocity=31, pitch=94)
# Item(name=Note, start=720, end=787, velocity=83, pitch=99)
# Item(name=Note, start=720, end=802, velocity=27, pitch=75)
# Item(name=Note, start=720, end=802, velocity=83, pitch=82)
# Item(name=Note, start=720, end=802, velocity=27, pitch=91)
# Item(name=Note, start=720, end=769, velocity=27, pitch=99)
# Item(name=Note, start=720, end=802, velocity=35, pitch=101)
# Item(name=Note, start=840, end=922, velocity=39, pitch=82)
# Item(name=Note, start=840, end=934, velocity=27, pitch=91)
# Item(name=Note, start=840, end=904, velocity=31, pitch=95)
# Item(name=Note, start=840, end=888, velocity=35, pitch=99)
# Item(name=Note, start=840, end=906, velocity=87, pitch=99)
# Item(name=Note, start=840, end=936, velocity=83, pitch=99)
# Item(name=Note, start=840, end=930, velocity=39, pitch=103)
# Item(name=Note, start=840, end=914, velocity=27, pitch=103)
# Item(name=Note, start=840, end=913, velocity=87, pitch=99)
# Item(name=Note, start=840, end=916, velocity=87, pitch=103)
# Item(name=Note, start=840, end=916, velocity=83, pitch=103)
# Item(name=Note, start=840, end=920, velocity=83, pitch=103)
# Item(name=Note, start=840, end=841, velocity=39, pitch=65)
# Item(name=Note, start=840, end=843, velocity=43, pitch=65)
# Item(name=Note, start=840, end=857, velocity=83, pitch=94)
# Item(name=Note, start=840, end=871, velocity=83, pitch=96)
# Item(name=Note, start=840, end=880, velocity=31, pitch=96)
# Item(name=Note, start=840, end=896, velocity=83, pitch=99)
# Item(name=Note, start=840, end=874, velocity=27, pitch=101)
# Item(name=Note, start=840, end=900, velocity=31, pitch=63)
# Item(name=Note, start=840, end=843, velocity=39, pitch=75)
# Item(name=Note, start=840, end=916, velocity=23, pitch=96)
# Item(name=Note, start=840, end=922, velocity=87, pitch=96)
# Item(name=Note, start=840, end=878, velocity=47, pitch=101)
# Item(name=Note, start=840, end=864, velocity=83, pitch=46)
# Item(name=Note, start=840, end=876, velocity=27, pitch=53)
# Item(name=Note, start=840, end=853, velocity=23, pitch=54)
# Item(name=Note, start=840, end=868, velocity=35, pitch=55)
# Item(name=Note, start=840, end=845, velocity=31, pitch=58)
# Item(name=Note, start=840, end=862, velocity=59, pitch=58)
# Item(name=Note, start=840, end=872, velocity=63, pitch=61)
# Item(name=Note, start=840, end=928, velocity=83, pitch=63)
# Item(name=Note, start=840, end=848, velocity=71, pitch=65)
# Item(name=Note, start=840, end=890, velocity=55, pitch=65)
# Item(name=Note, start=840, end=898, velocity=63, pitch=65)
# Item(name=Note, start=840, end=849, velocity=67, pitch=70)
# Item(name=Note, start=840, end=870, velocity=43, pitch=70)
# Item(name=Note, start=840, end=922, velocity=83, pitch=70)
# Item(name=Note, start=840, end=849, velocity=39, pitch=72)
# Item(name=Note, start=840, end=859, velocity=79, pitch=72)
# Item(name=Note, start=840, end=866, velocity=55, pitch=72)
# Item(name=Note, start=840, end=870, velocity=63, pitch=72)
# Item(name=Note, start=840, end=922, velocity=31, pitch=72)
# Item(name=Note, start=840, end=848, velocity=83, pitch=75)
# Item(name=Note, start=840, end=854, velocity=83, pitch=75)
# Item(name=Note, start=840, end=871, velocity=83, pitch=75)
# Item(name=Note, start=840, end=876, velocity=83, pitch=75)
# Item(name=Note, start=840, end=878, velocity=79, pitch=75)
# Item(name=Note, start=840, end=916, velocity=83, pitch=75)
# Item(name=Note, start=840, end=920, velocity=27, pitch=75)
# Item(name=Note, start=840, end=841, velocity=83, pitch=77)
# Item(name=Note, start=840, end=844, velocity=83, pitch=77)
# Item(name=Note, start=840, end=847, velocity=47, pitch=77)
# Item(name=Note, start=840, end=848, velocity=83, pitch=77)
# Item(name=Note, start=840, end=849, velocity=75, pitch=77)
# Item(name=Note, start=840, end=851, velocity=75, pitch=77)
# Item(name=Note, start=840, end=856, velocity=79, pitch=77)
# Item(name=Note, start=840, end=872, velocity=67, pitch=77)
# Item(name=Note, start=840, end=882, velocity=63, pitch=77)
# Item(name=Note, start=840, end=914, velocity=35, pitch=77)
# Item(name=Note, start=840, end=849, velocity=39, pitch=78)
# Item(name=Note, start=840, end=934, velocity=31, pitch=78)
# Item(name=Note, start=840, end=849, velocity=79, pitch=79)
# Item(name=Note, start=840, end=858, velocity=83, pitch=79)
# Item(name=Note, start=840, end=882, velocity=43, pitch=79)
# Item(name=Note, start=840, end=863, velocity=31, pitch=80)
# Item(name=Note, start=840, end=892, velocity=83, pitch=80)
# Item(name=Note, start=840, end=936, velocity=83, pitch=80)
# Item(name=Note, start=840, end=861, velocity=79, pitch=82)
# Item(name=Note, start=840, end=906, velocity=83, pitch=82)
# Item(name=Note, start=840, end=844, velocity=35, pitch=84)
# Item(name=Note, start=840, end=868, velocity=39, pitch=84)
# Item(name=Note, start=840, end=872, velocity=43, pitch=84)
# Item(name=Note, start=840, end=874, velocity=83, pitch=84)
# Item(name=Note, start=840, end=858, velocity=83, pitch=85)
# Item(name=Note, start=840, end=858, velocity=83, pitch=87)
# Item(name=Note, start=840, end=870, velocity=83, pitch=87)
# Item(name=Note, start=840, end=874, velocity=87, pitch=87)
# Item(name=Note, start=840, end=859, velocity=83, pitch=89)
# Item(name=Note, start=840, end=856, velocity=35, pitch=92)
# Item(name=Note, start=840, end=853, velocity=83, pitch=94)
# Item(name=Note, start=840, end=922, velocity=27, pitch=94)
# Item(name=Note, start=840, end=920, velocity=83, pitch=96)
# Item(name=Note, start=840, end=922, velocity=27, pitch=96)
# Item(name=Note, start=840, end=898, velocity=83, pitch=99)
# Item(name=Note, start=840, end=924, velocity=83, pitch=99)
# Item(name=Note, start=840, end=934, velocity=87, pitch=99)
# Item(name=Note, start=840, end=893, velocity=23, pitch=101)
# Item(name=Note, start=840, end=928, velocity=27, pitch=102)
# Item(name=Note, start=840, end=916, velocity=35, pitch=65)
# Item(name=Note, start=840, end=888, velocity=39, pitch=67)
# Item(name=Note, start=840, end=930, velocity=47, pitch=72)
# Item(name=Note, start=840, end=888, velocity=51, pitch=79)
# Item(name=Note, start=840, end=888, velocity=83, pitch=84)
# Item(name=Note, start=840, end=914, velocity=83, pitch=84)
# Item(name=Note, start=840, end=922, velocity=83, pitch=87)
# Item(name=Note, start=840, end=890, velocity=35, pitch=89)
# Item(name=Note, start=840, end=857, velocity=31, pitch=25)
# Item(name=Note, start=840, end=892, velocity=83, pitch=101)
# Item(name=Note, start=840, end=921, velocity=87, pitch=101)
# Item(name=Note, start=840, end=877, velocity=83, pitch=103)
# Item(name=Note, start=840, end=932, velocity=27, pitch=103)
# Item(name=Note, start=840, end=912, velocity=23, pitch=75)
# Item(name=Note, start=840, end=912, velocity=83, pitch=75)
# Item(name=Note, start=840, end=936, velocity=83, pitch=75)
# Item(name=Note, start=840, end=914, velocity=83, pitch=79)
# Item(name=Note, start=840, end=936, velocity=35, pitch=79)
# Item(name=Note, start=840, end=936, velocity=87, pitch=84)
# Item(name=Note, start=840, end=936, velocity=83, pitch=99)
# Item(name=Note, start=960, end=978, velocity=87, pitch=46)
# Item(name=Note, start=960, end=994, velocity=79, pitch=53)
# Item(name=Note, start=960, end=996, velocity=83, pitch=58)
# Item(name=Note, start=960, end=1004, velocity=51, pitch=62)
# Item(name=Note, start=960, end=1026, velocity=31, pitch=69)
# Item(name=Note, start=960, end=1010, velocity=55, pitch=72)
# Item(name=Note, start=960, end=968, velocity=35, pitch=77)
# Item(name=Note, start=960, end=1030, velocity=35, pitch=86)
# Item(name=Note, start=960, end=961, velocity=39, pitch=89)
# Item(name=Note, start=960, end=1056, velocity=51, pitch=91)
# Item(name=Note, start=960, end=1010, velocity=35, pitch=79)
# 1920

# %% [markdown]
# ### 5. Items 2 Events

# %%
events = item2event(groups)

print('Events')
print(*events[:10], sep='\n')
# Out:
# Events
# Event(name=Bar, time=None, value=None, text=1)
# Event(name=Position, time=0, value=1/16, text=0)
# Event(name=Tempo Class, time=0, value=mid, text=None)
# Event(name=Tempo Value, time=0, value=30, text=None)
# Event(name=Position, time=0, value=1/16, text=0)
# Event(name=Note Velocity, time=0, value=7, text=31/28)
# Event(name=Note On, time=0, value=65, text=65)
# Event(name=Note Duration, time=0, value=0, text=1/60)
# Event(name=Position, time=0, value=1/16, text=0)
# Event(name=Note Velocity, time=0, value=9, text=39/36)

# %% [markdown]
# ### 6. Events 2 Tokens

# %%
# read your dictionary
event2word, word2event = pickle.load(open('./basic_event_dictionary.pkl', 'rb'))

words = []
for event in events:
    e = '{}_{}'.format(event.name, event.value)
    if e in event2word:
        words.append(event2word[e])
    else:
        # OOV
        if event.name == 'Note Velocity':
            # replace with max velocity based on our training data
            words.append(event2word['Note Velocity_21'])
        else:
            # something is wrong
            # you should handle it for your own purpose
            print('something is wrong! {}'.format(e))

print('Tokens')
print(words[:10])
# Out:
# Tokens
# [0, 1, 18, 50, 1, 84, 142, 185, 1, 86]

# %% [markdown]
# ### 7. Play Music

# %%
import pygame

def play_music(midi_filename):
  '''Stream music_file in a blocking manner'''
  clock = pygame.time.Clock()
  pygame.mixer.music.load(midi_filename)
  pygame.mixer.music.play()
  while pygame.mixer.music.get_busy():
    clock.tick(30) # check if playback has finished
    
midi_filename = path

# mixer config
freq = 44100  # audio CD quality
bitsize = -16   # unsigned 16 bit
channels = 2  # 1 is mono, 2 is stereo
buffer = 1024   # number of samples
pygame.mixer.init(freq, bitsize, channels, buffer)

# optional volume 0 to 1.0
pygame.mixer.music.set_volume(0.8)

# listen for interruptions
try:
  # use the midi file you just saved
  play_music(midi_filename)
except KeyboardInterrupt:
  # if user hits Ctrl/C then exit
  # (works only in console mode)
  pygame.mixer.music.fadeout(1000)
  pygame.mixer.music.stop()
  raise SystemExit

# %% [markdown]
# # Hugging-Face tutorial

# %% [markdown]
# ## Import packages

# %%
from transformers import TransfoXLConfig, TransfoXLModel
import torch

# %% [markdown]
# ## Call the API

# %%
# you can change the parameters of the config
configuration = TransfoXLConfig()
model = TransfoXLModel(configuration)

# %%
configuration
# Out:
# TransfoXLConfig {
#   "adaptive": true,
#   "attn_type": 0,
#   "clamp_len": 1000,
#   "cutoffs": [
#     20000,
#     40000,
#     200000
#   ],
#   "d_embed": 1024,
#   "d_head": 64,
#   "d_inner": 4096,
#   "d_model": 1024,
#   "div_val": 4,
#   "dropatt": 0.0,
#   "dropout": 0.1,
#   "eos_token_id": 0,
#   "init": "normal",
#   "init_range": 0.01,
#   "init_std": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "mem_len": 1600,
#   "model_type": "transfo-xl",
#   "n_head": 16,
#   "n_layer": 18,
#   "pre_lnorm": false,
#   "proj_init_std": 0.01,
#   "same_length": true,
#   "sample_softmax": -1,
#   "tie_projs": [
#     false,
#     true,
#     true,
#     true
#   ],
#   "transformers_version": "4.26.0",
#   "untie_r": true,
#   "vocab_size": 267735
# }

# %%
x = torch.randint(0, configuration.vocab_size, (1, 512))
y = model(x)
output = y['last_hidden_state'] # outputshape = (batch, x_len, d_embed)
