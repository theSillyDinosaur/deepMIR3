# %% [markdown]
# # Please install the packages below to run the code

# %% [markdown]
# numpy == 1.23.5
#
# miditoolkit
#
# transformers
#
# torch

# %% [markdown]
# # Midi tutorial

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import miditoolkit
import copy
import pickle

# %% [markdown]
# ## Some functions

# %%
# parameters for input
DEFAULT_VELOCITY_BINS = np.linspace(0, 128, 32+1, dtype=int)
DEFAULT_FRACTION = 16
DEFAULT_DURATION_BINS = np.arange(60, 3841, 60, dtype=int)
DEFAULT_TEMPO_INTERVALS = [range(30, 90), range(90, 150), range(150, 210)]

# parameters for output
DEFAULT_RESOLUTION = 480

# define "Item" for general storage
class Item(object):
    def __init__(self, name, start, end, velocity, pitch):
        self.name = name
        self.start = start
        self.end = end
        self.velocity = velocity
        self.pitch = pitch

    def __repr__(self):
        return 'Item(name={}, start={}, end={}, velocity={}, pitch={})'.format(
            self.name, self.start, self.end, self.velocity, self.pitch)

# read notes and tempo changes from midi (assume there is only one track)
def read_items(file_path):
    midi_obj = miditoolkit.midi.parser.MidiFile(file_path)
    # note
    note_items = []
    notes = midi_obj.instruments[0].notes
    notes.sort(key=lambda x: (x.start, x.pitch))
    for note in notes:
        note_items.append(Item(
            name='Note', 
            start=note.start, 
            end=note.end, 
            velocity=note.velocity, 
            pitch=note.pitch))
    note_items.sort(key=lambda x: x.start)
    # tempo
    tempo_items = []
    for tempo in midi_obj.tempo_changes:
        tempo_items.append(Item(
            name='Tempo',
            start=tempo.time,
            end=None,
            velocity=None,
            pitch=int(tempo.tempo)))
    tempo_items.sort(key=lambda x: x.start)
    # expand to all beat
    max_tick = tempo_items[-1].start
    existing_ticks = {item.start: item.pitch for item in tempo_items}
    wanted_ticks = np.arange(0, max_tick+1, DEFAULT_RESOLUTION)
    output = []
    for tick in wanted_ticks:
        if tick in existing_ticks:
            output.append(Item(
                name='Tempo',
                start=tick,
                end=None,
                velocity=None,
                pitch=existing_ticks[tick]))
        else:
            output.append(Item(
                name='Tempo',
                start=tick,
                end=None,
                velocity=None,
                pitch=output[-1].pitch))
    tempo_items = output
    return note_items, tempo_items

# quantize items
def quantize_items(items, ticks=120):
    # grid
    grids = np.arange(0, items[-1].start, ticks, dtype=int)
    # process
    for item in items:
        index = np.argmin(abs(grids - item.start))
        shift = grids[index] - item.start
        item.start += shift
        item.end += shift
    return items      

# extract chord
def chord_extract(midi_path, max_time):
    midi_obj = miditoolkit.midi.parser.MidiFile(midi_path)
    interval = midi_obj.ticks_per_beat * 1
    chord_items = []
    ###
    # implement your chord extraction here
    # it's fine if you don't use chord items
    ###
    return chord_items

# group items
def group_items(items, max_time, ticks_per_bar=DEFAULT_RESOLUTION*4):
    items.sort(key=lambda x: x.start)
    downbeats = np.arange(0, max_time+ticks_per_bar, ticks_per_bar)
    groups = []
    for db1, db2 in zip(downbeats[:-1], downbeats[1:]):
        insiders = []
        for item in items:
            if (item.start >= db1) and (item.start < db2):
                insiders.append(item)
        overall = [db1] + insiders + [db2]
        groups.append(overall)
    return groups

# define "Event" for event storage
class Event(object):
    def __init__(self, name, time, value, text):
        self.name = name
        self.time = time
        self.value = value
        self.text = text

    def __repr__(self):
        return 'Event(name={}, time={}, value={}, text={})'.format(
            self.name, self.time, self.value, self.text)

# item to event
def item2event(groups):
    events = []
    n_downbeat = 0
    for i in range(len(groups)):
        if 'Note' not in [item.name for item in groups[i][1:-1]]:
            continue
        bar_st, bar_et = groups[i][0], groups[i][-1]
        n_downbeat += 1
        events.append(Event(
            name='Bar',
            time=None, 
            value=None,
            text='{}'.format(n_downbeat)))
        for item in groups[i][1:-1]:
            # position
            flags = np.linspace(bar_st, bar_et, DEFAULT_FRACTION, endpoint=False)
            index = np.argmin(abs(flags-item.start))
            events.append(Event(
                name='Position', 
                time=item.start,
                value='{}/{}'.format(index+1, DEFAULT_FRACTION),
                text='{}'.format(item.start)))
            if item.name == 'Note':
                # velocity
                velocity_index = np.searchsorted(
                    DEFAULT_VELOCITY_BINS, 
                    item.velocity, 
                    side='right') - 1
                events.append(Event(
                    name='Note Velocity',
                    time=item.start, 
                    value=velocity_index,
                    text='{}/{}'.format(item.velocity, DEFAULT_VELOCITY_BINS[velocity_index])))
                # pitch
                events.append(Event(
                    name='Note On',
                    time=item.start, 
                    value=item.pitch,
                    text='{}'.format(item.pitch)))
                # duration
                duration = item.end - item.start
                index = np.argmin(abs(DEFAULT_DURATION_BINS-duration))
                events.append(Event(
                    name='Note Duration',
                    time=item.start,
                    value=index,
                    text='{}/{}'.format(duration, DEFAULT_DURATION_BINS[index])))
            elif item.name == 'Chord':
                events.append(Event(
                    name='Chord', 
                    time=item.start,
                    value=item.pitch,
                    text='{}'.format(item.pitch)))
            elif item.name == 'Tempo':
                tempo = item.pitch
                if tempo in DEFAULT_TEMPO_INTERVALS[0]:
                    tempo_style = Event('Tempo Class', item.start, 'slow', None)
                    tempo_value = Event('Tempo Value', item.start, 
                        tempo-DEFAULT_TEMPO_INTERVALS[0].start, None)
                elif tempo in DEFAULT_TEMPO_INTERVALS[1]:
                    tempo_style = Event('Tempo Class', item.start, 'mid', None)
                    tempo_value = Event('Tempo Value', item.start, 
                        tempo-DEFAULT_TEMPO_INTERVALS[1].start, None)
                elif tempo in DEFAULT_TEMPO_INTERVALS[2]:
                    tempo_style = Event('Tempo Class', item.start, 'fast', None)
                    tempo_value = Event('Tempo Value', item.start, 
                        tempo-DEFAULT_TEMPO_INTERVALS[2].start, None)
                elif tempo < DEFAULT_TEMPO_INTERVALS[0].start:
                    tempo_style = Event('Tempo Class', item.start, 'slow', None)
                    tempo_value = Event('Tempo Value', item.start, 0, None)
                elif tempo > DEFAULT_TEMPO_INTERVALS[2].stop:
                    tempo_style = Event('Tempo Class', item.start, 'fast', None)
                    tempo_value = Event('Tempo Value', item.start, 59, None)
                events.append(tempo_style)
                events.append(tempo_value)     
    return events

#############################################################################################
# WRITE MIDI
#############################################################################################
def word_to_event(words, word2event):
    events = []
    for word in words:
        event_name, event_value = word2event.get(word).split('_')
        events.append(Event(event_name, None, event_value, None))
    return events

def write_midi(words, word2event, output_path, prompt_path=None):
    events = word_to_event(words, word2event)
    # get downbeat and note (no time)
    temp_notes = []
    temp_chords = []
    temp_tempos = []
    for i in range(len(events)-3):
        if events[i].name == 'Bar' and i > 0:
            temp_notes.append('Bar')
            temp_chords.append('Bar')
            temp_tempos.append('Bar')
        elif events[i].name == 'Position' and \
            events[i+1].name == 'Note Velocity' and \
            events[i+2].name == 'Note On' and \
            events[i+3].name == 'Note Duration':
            # start time and end time from position
            position = int(events[i].value.split('/')[0]) - 1
            # velocity
            index = int(events[i+1].value)
            velocity = int(DEFAULT_VELOCITY_BINS[index])
            # pitch
            pitch = int(events[i+2].value)
            # duration
            index = int(events[i+3].value)
            duration = DEFAULT_DURATION_BINS[index]
            # adding
            temp_notes.append([position, velocity, pitch, duration])
        elif events[i].name == 'Position' and events[i+1].name == 'Chord':
            position = int(events[i].value.split('/')[0]) - 1
            temp_chords.append([position, events[i+1].value])
        elif events[i].name == 'Position' and \
            events[i+1].name == 'Tempo Class' and \
            events[i+2].name == 'Tempo Value':
            position = int(events[i].value.split('/')[0]) - 1
            if events[i+1].value == 'slow':
                tempo = DEFAULT_TEMPO_INTERVALS[0].start + int(events[i+2].value)
            elif events[i+1].value == 'mid':
                tempo = DEFAULT_TEMPO_INTERVALS[1].start + int(events[i+2].value)
            elif events[i+1].value == 'fast':
                tempo = DEFAULT_TEMPO_INTERVALS[2].start + int(events[i+2].value)
            temp_tempos.append([position, tempo])
    # get specific time for notes
    ticks_per_beat = DEFAULT_RESOLUTION
    ticks_per_bar = DEFAULT_RESOLUTION * 4 # assume 4/4
    notes = []
    current_bar = 0
    for note in temp_notes:
        if note == 'Bar':
            current_bar += 1
        else:
            position, velocity, pitch, duration = note
            # position (start time)
            current_bar_st = current_bar * ticks_per_bar
            current_bar_et = (current_bar + 1) * ticks_per_bar
            flags = np.linspace(current_bar_st, current_bar_et, DEFAULT_FRACTION, endpoint=False, dtype=int)
            st = flags[position]
            # duration (end time)
            et = st + duration
            notes.append(miditoolkit.Note(velocity, pitch, st, et))
    # get specific time for chords
    if len(temp_chords) > 0:
        chords = []
        current_bar = 0
        for chord in temp_chords:
            if chord == 'Bar':
                current_bar += 1
            else:
                position, value = chord
                # position (start time)
                current_bar_st = current_bar * ticks_per_bar
                current_bar_et = (current_bar + 1) * ticks_per_bar
                flags = np.linspace(current_bar_st, current_bar_et, DEFAULT_FRACTION, endpoint=False, dtype=int)
                st = flags[position]
                chords.append([st, value])
    # get specific time for tempos
    tempos = []
    current_bar = 0
    for tempo in temp_tempos:
        if tempo == 'Bar':
            current_bar += 1
        else:
            position, value = tempo
            # position (start time)
            current_bar_st = current_bar * ticks_per_bar
            current_bar_et = (current_bar + 1) * ticks_per_bar
            flags = np.linspace(current_bar_st, current_bar_et, DEFAULT_FRACTION, endpoint=False, dtype=int)
            st = flags[position]
            tempos.append([int(st), value])
    # write
    if prompt_path:
        midi = miditoolkit.midi.parser.MidiFile(prompt_path)
        #
        last_time = DEFAULT_RESOLUTION * 4 * 4
        # note shift
        for note in notes:
            note.start += last_time
            note.end += last_time
        midi.instruments[0].notes.extend(notes)
        # tempo changes
        temp_tempos = []
        for tempo in midi.tempo_changes:
            if tempo.time < DEFAULT_RESOLUTION*4*4:
                temp_tempos.append(tempo)
            else:
                break
        for st, bpm in tempos:
            st += last_time
            temp_tempos.append(miditoolkit.midi.containers.TempoChange(bpm, st))
        midi.tempo_changes = temp_tempos
        # write chord into marker
        if len(temp_chords) > 0:
            for c in chords:
                midi.markers.append(
                    miditoolkit.midi.containers.Marker(text=c[1], time=c[0]+last_time))
    else:
        midi = miditoolkit.midi.parser.MidiFile()
        midi.ticks_per_beat = DEFAULT_RESOLUTION
        # write instrument
        inst = miditoolkit.midi.containers.Instrument(0, is_drum=False)
        inst.notes = notes
        midi.instruments.append(inst)
        # write tempo
        tempo_changes = []
        for st, bpm in tempos:
            tempo_changes.append(miditoolkit.midi.containers.TempoChange(bpm, st))
        midi.tempo_changes = tempo_changes
        # write chord into marker
        if len(temp_chords) > 0:
            for c in chords:
                midi.markers.append(
                    miditoolkit.midi.containers.Marker(text=c[1], time=c[0]))
    # write
    midi.dump(output_path)

# %% [markdown]
# ## Convert midi 2 remi tokens

# %% [markdown]
# ### 0. Take a look at midi file

# %%
# change your midi file path here
path = '../test.mid'
midi = miditoolkit.midi.parser.MidiFile(path)
print(midi)
# Out:
# ticks per beat: 8
# max tick: 1220
# tempo changes: 1
# time sig: 1
# key sig: 0
# markers: 0
# lyrics: False
# instruments: 1

# %%
# notes
print('Notes')
for inst in midi.instruments:
    print(inst) 
    print(*inst.notes[0:10], sep='\n')
# temples
print('\nTempos')
print(*midi.tempo_changes[0:10], sep='\n')
# Out:
# Notes
# Instrument(program=0, is_drum=False, name=Acoustic Grand Piano) - 206 notes
# Note(velocity=43, pitch=57, start=31, end=40)
# Note(velocity=59, pitch=60, start=32, end=40)
# Note(velocity=43, pitch=41, start=32, end=40)
# Note(velocity=47, pitch=48, start=32, end=40)
# Note(velocity=55, pitch=53, start=32, end=40)
# Note(velocity=59, pitch=65, start=32, end=40)
# Note(velocity=63, pitch=69, start=33, end=41)
# Note(velocity=63, pitch=43, start=40, end=41)
# Note(velocity=67, pitch=50, start=40, end=41)
# Note(velocity=63, pitch=55, start=40, end=41)
#
# Tempos
# 120.0 BPM at 0 ticks

# %% [markdown]
# ### 1. Read midi and convert to Item object

# %%
note_items, tempo_items = read_items(path)

print('Note items')
print(*note_items[0:10], sep='\n')
print('\nTempo items')
print(*tempo_items[0:10], sep='\n')
# Out:
# Note items
# Item(name=Note, start=31, end=40, velocity=43, pitch=57)
# Item(name=Note, start=32, end=40, velocity=43, pitch=41)
# Item(name=Note, start=32, end=40, velocity=47, pitch=48)
# Item(name=Note, start=32, end=40, velocity=55, pitch=53)
# Item(name=Note, start=32, end=40, velocity=59, pitch=60)
# Item(name=Note, start=32, end=40, velocity=59, pitch=65)
# Item(name=Note, start=33, end=41, velocity=63, pitch=69)
# Item(name=Note, start=40, end=41, velocity=63, pitch=43)
# Item(name=Note, start=40, end=41, velocity=67, pitch=50)
# Item(name=Note, start=40, end=41, velocity=63, pitch=55)
#
# Tempo items
# Item(name=Tempo, start=0, end=None, velocity=None, pitch=120)

# %% [markdown]
# ### 2. Quantize note items

# %%
note_items = quantize_items(note_items)

print('Quantized note items')
print(*note_items[:10], sep='\n')
# Out:
# Quantized note items
# Item(name=Note, start=0, end=9, velocity=43, pitch=57)
# Item(name=Note, start=0, end=8, velocity=43, pitch=41)
# Item(name=Note, start=0, end=8, velocity=47, pitch=48)
# Item(name=Note, start=0, end=8, velocity=55, pitch=53)
# Item(name=Note, start=0, end=8, velocity=59, pitch=60)
# Item(name=Note, start=0, end=8, velocity=59, pitch=65)
# Item(name=Note, start=0, end=8, velocity=63, pitch=69)
# Item(name=Note, start=0, end=1, velocity=63, pitch=43)
# Item(name=Note, start=0, end=1, velocity=67, pitch=50)
# Item(name=Note, start=0, end=1, velocity=63, pitch=55)

# %% [markdown]
# ### 3. extract chord (if needed)

# %%
chord_items = chord_extract(path, note_items[-1].end)

print('Chord items')
print(*chord_items[:10], sep='\n')
# Out:
# Chord items

# %% [markdown]
# ### 4. group items

# %%
# if using chord items
# items = chord_items + tempo_items + note_items

# if not using chord items
items = tempo_items + note_items

max_time = note_items[-1].end
groups = group_items(items, max_time)

for g in groups:
    print(*g, sep='\n')
    print()
# Out:
# 0
# Item(name=Tempo, start=0, end=None, velocity=None, pitch=120)
# Item(name=Note, start=0, end=9, velocity=43, pitch=57)
# Item(name=Note, start=0, end=8, velocity=43, pitch=41)
# Item(name=Note, start=0, end=8, velocity=47, pitch=48)
# Item(name=Note, start=0, end=8, velocity=55, pitch=53)
# Item(name=Note, start=0, end=8, velocity=59, pitch=60)
# Item(name=Note, start=0, end=8, velocity=59, pitch=65)
# Item(name=Note, start=0, end=8, velocity=63, pitch=69)
# Item(name=Note, start=0, end=1, velocity=63, pitch=43)
# Item(name=Note, start=0, end=1, velocity=67, pitch=50)
# Item(name=Note, start=0, end=1, velocity=63, pitch=55)
# Item(name=Note, start=0, end=1, velocity=63, pitch=58)
# Item(name=Note, start=0, end=1, velocity=67, pitch=62)
# Item(name=Note, start=0, end=1, velocity=75, pitch=70)
# Item(name=Note, start=0, end=22, velocity=59, pitch=45)
# Item(name=Note, start=0, end=20, velocity=59, pitch=53)
# Item(name=Note, start=0, end=21, velocity=59, pitch=60)
# Item(name=Note, start=0, end=1, velocity=55, pitch=65)
# Item(name=Note, start=0, end=21, velocity=63, pitch=69)
# Item(name=Note, start=0, end=22, velocity=63, pitch=72)
# Item(name=Note, start=120, end=140, velocity=51, pitch=46)
# Item(name=Note, start=120, end=140, velocity=51, pitch=53)
# Item(name=Note, start=120, end=140, velocity=51, pitch=58)
# Item(name=Note, start=120, end=140, velocity=55, pitch=62)
# Item(name=Note, start=120, end=124, velocity=55, pitch=65)
# Item(name=Note, start=120, end=139, velocity=63, pitch=70)
# Item(name=Note, start=120, end=134, velocity=67, pitch=70)
# Item(name=Note, start=120, end=141, velocity=51, pitch=48)
# Item(name=Note, start=120, end=132, velocity=51, pitch=55)
# Item(name=Note, start=120, end=132, velocity=51, pitch=60)
# Item(name=Note, start=120, end=133, velocity=55, pitch=62)
# Item(name=Note, start=120, end=121, velocity=55, pitch=65)
# Item(name=Note, start=120, end=129, velocity=59, pitch=41)
# Item(name=Note, start=120, end=129, velocity=59, pitch=57)
# Item(name=Note, start=120, end=128, velocity=63, pitch=60)
# Item(name=Note, start=120, end=129, velocity=63, pitch=65)
# Item(name=Note, start=120, end=129, velocity=67, pitch=69)
# Item(name=Note, start=120, end=121, velocity=63, pitch=43)
# Item(name=Note, start=120, end=121, velocity=63, pitch=58)
# Item(name=Note, start=120, end=121, velocity=63, pitch=62)
# Item(name=Note, start=120, end=121, velocity=75, pitch=70)
# Item(name=Note, start=120, end=141, velocity=63, pitch=45)
# Item(name=Note, start=120, end=140, velocity=59, pitch=53)
# Item(name=Note, start=120, end=141, velocity=63, pitch=60)
# Item(name=Note, start=120, end=139, velocity=59, pitch=65)
# Item(name=Note, start=120, end=141, velocity=67, pitch=69)
# Item(name=Note, start=120, end=141, velocity=71, pitch=72)
# Item(name=Note, start=120, end=141, velocity=47, pitch=62)
# Item(name=Note, start=120, end=141, velocity=51, pitch=46)
# Item(name=Note, start=120, end=141, velocity=47, pitch=53)
# Item(name=Note, start=120, end=140, velocity=51, pitch=58)
# Item(name=Note, start=120, end=122, velocity=51, pitch=65)
# Item(name=Note, start=120, end=140, velocity=59, pitch=70)
# Item(name=Note, start=120, end=141, velocity=63, pitch=74)
# Item(name=Note, start=120, end=133, velocity=51, pitch=43)
# Item(name=Note, start=120, end=132, velocity=47, pitch=48)
# Item(name=Note, start=120, end=121, velocity=47, pitch=55)
# Item(name=Note, start=120, end=133, velocity=51, pitch=62)
# Item(name=Note, start=120, end=124, velocity=55, pitch=65)
# Item(name=Note, start=120, end=133, velocity=63, pitch=70)
# Item(name=Note, start=120, end=128, velocity=67, pitch=65)
# Item(name=Note, start=120, end=125, velocity=71, pitch=67)
# Item(name=Note, start=120, end=122, velocity=55, pitch=60)
# Item(name=Note, start=120, end=122, velocity=55, pitch=65)
# Item(name=Note, start=120, end=132, velocity=55, pitch=41)
# Item(name=Note, start=120, end=132, velocity=59, pitch=48)
# Item(name=Note, start=120, end=130, velocity=43, pitch=50)
# Item(name=Note, start=120, end=132, velocity=67, pitch=69)
# Item(name=Note, start=120, end=129, velocity=43, pitch=73)
# Item(name=Note, start=120, end=129, velocity=47, pitch=74)
# Item(name=Note, start=120, end=140, velocity=47, pitch=77)
# Item(name=Note, start=120, end=128, velocity=75, pitch=72)
# Item(name=Note, start=120, end=124, velocity=63, pitch=43)
# Item(name=Note, start=120, end=124, velocity=59, pitch=50)
# Item(name=Note, start=120, end=124, velocity=67, pitch=55)
# Item(name=Note, start=120, end=125, velocity=71, pitch=74)
# Item(name=Note, start=120, end=124, velocity=79, pitch=24)
# Item(name=Note, start=120, end=130, velocity=83, pitch=86)
# Item(name=Note, start=120, end=139, velocity=47, pitch=100)
# Item(name=Note, start=120, end=208, velocity=35, pitch=103)
# Item(name=Note, start=120, end=141, velocity=67, pitch=45)
# Item(name=Note, start=120, end=140, velocity=59, pitch=53)
# Item(name=Note, start=120, end=126, velocity=27, pitch=57)
# Item(name=Note, start=120, end=125, velocity=39, pitch=60)
# Item(name=Note, start=120, end=138, velocity=63, pitch=67)
# Item(name=Note, start=120, end=133, velocity=71, pitch=77)
# Item(name=Note, start=120, end=212, velocity=83, pitch=86)
# Item(name=Note, start=120, end=150, velocity=35, pitch=50)
# Item(name=Note, start=120, end=123, velocity=31, pitch=65)
# Item(name=Note, start=120, end=137, velocity=75, pitch=74)
# Item(name=Note, start=240, end=314, velocity=67, pitch=103)
# Item(name=Note, start=240, end=257, velocity=35, pitch=62)
# Item(name=Note, start=240, end=322, velocity=27, pitch=93)
# Item(name=Note, start=240, end=243, velocity=39, pitch=81)
# Item(name=Note, start=240, end=322, velocity=39, pitch=81)
# Item(name=Note, start=240, end=257, velocity=27, pitch=83)
# Item(name=Note, start=240, end=249, velocity=31, pitch=62)
# Item(name=Note, start=240, end=328, velocity=35, pitch=69)
# Item(name=Note, start=240, end=336, velocity=83, pitch=96)
# Item(name=Note, start=360, end=442, velocity=39, pitch=103)
# Item(name=Note, start=360, end=442, velocity=83, pitch=103)
# Item(name=Note, start=360, end=450, velocity=35, pitch=74)
# Item(name=Note, start=360, end=377, velocity=31, pitch=62)
# Item(name=Note, start=360, end=446, velocity=27, pitch=81)
# Item(name=Note, start=360, end=430, velocity=43, pitch=91)
# Item(name=Note, start=480, end=572, velocity=31, pitch=39)
# Item(name=Note, start=480, end=556, velocity=31, pitch=55)
# Item(name=Note, start=480, end=498, velocity=31, pitch=58)
# Item(name=Note, start=480, end=576, velocity=27, pitch=99)
# Item(name=Note, start=480, end=485, velocity=27, pitch=27)
# Item(name=Note, start=480, end=572, velocity=83, pitch=27)
# Item(name=Note, start=480, end=483, velocity=39, pitch=79)
# Item(name=Note, start=480, end=572, velocity=23, pitch=79)
# Item(name=Note, start=480, end=556, velocity=27, pitch=89)
# Item(name=Note, start=480, end=547, velocity=27, pitch=91)
# Item(name=Note, start=480, end=530, velocity=31, pitch=93)
# Item(name=Note, start=480, end=572, velocity=35, pitch=103)
# Item(name=Note, start=480, end=572, velocity=27, pitch=103)
# Item(name=Note, start=480, end=576, velocity=31, pitch=98)
# Item(name=Note, start=480, end=572, velocity=83, pitch=103)
# Item(name=Note, start=600, end=640, velocity=27, pitch=91)
# Item(name=Note, start=600, end=630, velocity=27, pitch=94)
# Item(name=Note, start=600, end=682, velocity=27, pitch=103)
# Item(name=Note, start=600, end=662, velocity=27, pitch=79)
# Item(name=Note, start=600, end=660, velocity=83, pitch=82)
# Item(name=Note, start=600, end=692, velocity=83, pitch=82)
# Item(name=Note, start=600, end=694, velocity=27, pitch=79)
# Item(name=Note, start=600, end=696, velocity=83, pitch=82)
# Item(name=Note, start=600, end=654, velocity=23, pitch=91)
# Item(name=Note, start=600, end=692, velocity=31, pitch=94)
# Item(name=Note, start=600, end=676, velocity=27, pitch=93)
# Item(name=Note, start=600, end=696, velocity=27, pitch=79)
# Item(name=Note, start=600, end=680, velocity=87, pitch=94)
# Item(name=Note, start=600, end=664, velocity=87, pitch=100)
# Item(name=Note, start=600, end=684, velocity=27, pitch=103)
# Item(name=Note, start=600, end=682, velocity=27, pitch=103)
# Item(name=Note, start=600, end=674, velocity=39, pitch=79)
# Item(name=Note, start=600, end=674, velocity=83, pitch=81)
# Item(name=Note, start=600, end=617, velocity=31, pitch=98)
# Item(name=Note, start=600, end=670, velocity=83, pitch=102)
# Item(name=Note, start=600, end=603, velocity=31, pitch=27)
# Item(name=Note, start=600, end=660, velocity=35, pitch=39)
# Item(name=Note, start=600, end=660, velocity=71, pitch=92)
# Item(name=Note, start=600, end=686, velocity=83, pitch=94)
# Item(name=Note, start=600, end=664, velocity=83, pitch=103)
# Item(name=Note, start=600, end=682, velocity=35, pitch=98)
# Item(name=Note, start=600, end=692, velocity=31, pitch=102)
# Item(name=Note, start=720, end=721, velocity=35, pitch=74)
# Item(name=Note, start=720, end=788, velocity=83, pitch=91)
# Item(name=Note, start=720, end=756, velocity=83, pitch=99)
# Item(name=Note, start=720, end=812, velocity=31, pitch=86)
# Item(name=Note, start=720, end=754, velocity=27, pitch=95)
# Item(name=Note, start=720, end=814, velocity=87, pitch=97)
# Item(name=Note, start=720, end=749, velocity=87, pitch=101)
# Item(name=Note, start=720, end=770, velocity=39, pitch=69)
# Item(name=Note, start=720, end=745, velocity=39, pitch=103)
# Item(name=Note, start=720, end=806, velocity=87, pitch=104)
# Item(name=Note, start=720, end=774, velocity=83, pitch=80)
# Item(name=Note, start=720, end=770, velocity=79, pitch=90)
# Item(name=Note, start=720, end=802, velocity=87, pitch=98)
# Item(name=Note, start=720, end=806, velocity=83, pitch=58)
# Item(name=Note, start=720, end=739, velocity=31, pitch=27)
# Item(name=Note, start=720, end=786, velocity=31, pitch=70)
# Item(name=Note, start=720, end=800, velocity=31, pitch=78)
# Item(name=Note, start=720, end=802, velocity=87, pitch=80)
# Item(name=Note, start=720, end=808, velocity=83, pitch=101)
# Item(name=Note, start=720, end=796, velocity=27, pitch=101)
# Item(name=Note, start=840, end=936, velocity=39, pitch=67)
# Item(name=Note, start=840, end=936, velocity=27, pitch=83)
# Item(name=Note, start=840, end=934, velocity=83, pitch=94)
# Item(name=Note, start=840, end=880, velocity=35, pitch=101)
# Item(name=Note, start=840, end=873, velocity=31, pitch=101)
# Item(name=Note, start=840, end=910, velocity=35, pitch=103)
# Item(name=Note, start=840, end=928, velocity=83, pitch=93)
# Item(name=Note, start=840, end=922, velocity=83, pitch=104)
# Item(name=Note, start=840, end=878, velocity=83, pitch=99)
# Item(name=Note, start=840, end=922, velocity=83, pitch=101)
# Item(name=Note, start=840, end=922, velocity=31, pitch=103)
# Item(name=Note, start=840, end=936, velocity=27, pitch=101)
# Item(name=Note, start=960, end=1042, velocity=39, pitch=98)
# Item(name=Note, start=960, end=977, velocity=39, pitch=100)
# Item(name=Note, start=960, end=1042, velocity=83, pitch=102)
# Item(name=Note, start=960, end=1052, velocity=35, pitch=101)
# Item(name=Note, start=960, end=1042, velocity=35, pitch=104)
# Item(name=Note, start=960, end=1040, velocity=27, pitch=101)
# Item(name=Note, start=1080, end=1146, velocity=83, pitch=58)
# Item(name=Note, start=1080, end=1134, velocity=27, pitch=74)
# Item(name=Note, start=1080, end=1162, velocity=87, pitch=99)
# Item(name=Note, start=1080, end=1172, velocity=87, pitch=101)
# Item(name=Note, start=1080, end=1116, velocity=83, pitch=102)
# Item(name=Note, start=1080, end=1170, velocity=83, pitch=104)
# Item(name=Note, start=1080, end=1170, velocity=87, pitch=94)
# Item(name=Note, start=1080, end=1156, velocity=83, pitch=96)
# Item(name=Note, start=1080, end=1160, velocity=87, pitch=101)
# Item(name=Note, start=1080, end=1162, velocity=31, pitch=94)
# Item(name=Note, start=1080, end=1150, velocity=31, pitch=24)
# Item(name=Note, start=1080, end=1122, velocity=31, pitch=26)
# Item(name=Note, start=1080, end=1154, velocity=31, pitch=101)
# Item(name=Note, start=1080, end=1170, velocity=27, pitch=101)
# Item(name=Note, start=1080, end=1162, velocity=31, pitch=103)
# Item(name=Note, start=1080, end=1172, velocity=27, pitch=105)
# Item(name=Note, start=1080, end=1146, velocity=27, pitch=77)
# Item(name=Note, start=1080, end=1162, velocity=83, pitch=104)
# Item(name=Note, start=1080, end=1176, velocity=83, pitch=105)
# Item(name=Note, start=1080, end=1081, velocity=39, pitch=91)
# Item(name=Note, start=1080, end=1164, velocity=87, pitch=96)
# Item(name=Note, start=1080, end=1162, velocity=27, pitch=93)
# 1920

# %% [markdown]
# ### 5. Items 2 Events

# %%
events = item2event(groups)

print('Events')
print(*events[:10], sep='\n')
# Out:
# Events
# Event(name=Bar, time=None, value=None, text=1)
# Event(name=Position, time=0, value=1/16, text=0)
# Event(name=Tempo Class, time=0, value=mid, text=None)
# Event(name=Tempo Value, time=0, value=30, text=None)
# Event(name=Position, time=0, value=1/16, text=0)
# Event(name=Note Velocity, time=0, value=10, text=43/40)
# Event(name=Note On, time=0, value=57, text=57)
# Event(name=Note Duration, time=0, value=0, text=9/60)
# Event(name=Position, time=0, value=1/16, text=0)
# Event(name=Note Velocity, time=0, value=10, text=43/40)

# %% [markdown]
# ### 6. Events 2 Tokens

# %%
# read your dictionary
event2word, word2event = pickle.load(open('./basic_event_dictionary.pkl', 'rb'))

words = []
for event in events:
    e = '{}_{}'.format(event.name, event.value)
    if e in event2word:
        words.append(event2word[e])
    else:
        # OOV
        if event.name == 'Note Velocity':
            # replace with max velocity based on our training data
            words.append(event2word['Note Velocity_21'])
        else:
            # something is wrong
            # you should handle it for your own purpose
            print('something is wrong! {}'.format(e))

print('Tokens')
print(words[:10])
# Out:
# Tokens
# [0, 1, 18, 50, 1, 87, 134, 185, 1, 87]

# %% [markdown]
# ### 7. Play Music

# %%
import pygame

def play_music(midi_filename):
  '''Stream music_file in a blocking manner'''
  clock = pygame.time.Clock()
  pygame.mixer.music.load(midi_filename)
  pygame.mixer.music.play()
  while pygame.mixer.music.get_busy():
    clock.tick(30) # check if playback has finished
    
midi_filename = path

# mixer config
freq = 44100  # audio CD quality
bitsize = -16   # unsigned 16 bit
channels = 2  # 1 is mono, 2 is stereo
buffer = 1024   # number of samples
pygame.mixer.init(freq, bitsize, channels, buffer)

# optional volume 0 to 1.0
pygame.mixer.music.set_volume(0.8)

# listen for interruptions
try:
  # use the midi file you just saved
  play_music(midi_filename)
except KeyboardInterrupt:
  # if user hits Ctrl/C then exit
  # (works only in console mode)
  pygame.mixer.music.fadeout(1000)
  pygame.mixer.music.stop()
  raise SystemExit

# %% [markdown]
# # Hugging-Face tutorial

# %% [markdown]
# ## Import packages

# %%
from transformers import TransfoXLConfig, TransfoXLModel
import torch

# %% [markdown]
# ## Call the API

# %%
# you can change the parameters of the config
configuration = TransfoXLConfig()
model = TransfoXLModel(configuration)

# %%
configuration
# Out:
# TransfoXLConfig {
#   "adaptive": true,
#   "attn_type": 0,
#   "clamp_len": 1000,
#   "cutoffs": [
#     20000,
#     40000,
#     200000
#   ],
#   "d_embed": 1024,
#   "d_head": 64,
#   "d_inner": 4096,
#   "d_model": 1024,
#   "div_val": 4,
#   "dropatt": 0.0,
#   "dropout": 0.1,
#   "eos_token_id": 0,
#   "init": "normal",
#   "init_range": 0.01,
#   "init_std": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "mem_len": 1600,
#   "model_type": "transfo-xl",
#   "n_head": 16,
#   "n_layer": 18,
#   "pre_lnorm": false,
#   "proj_init_std": 0.01,
#   "same_length": true,
#   "sample_softmax": -1,
#   "tie_projs": [
#     false,
#     true,
#     true,
#     true
#   ],
#   "transformers_version": "4.26.0",
#   "untie_r": true,
#   "vocab_size": 267735
# }

# %%
x = torch.randint(0, configuration.vocab_size, (1, 512))
y = model(x)
output = y['last_hidden_state'] # outputshape = (batch, x_len, d_embed)
